# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import glob
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from fit_generator import label_from_id
import scipy
import util

# %%
source_path = '../converted/'

# %%
txt_files = glob.glob(source_path + '*')
len(txt_files)
# Out:
# 104785

# %%
util.tokenize_and_stem("to be or not to be that 1234 2017 is the question skiing-results question question")
# Out:
# ['not', 'that', 'the', 'question', 'ski', 'result', 'question', 'question']

# %%
count_vectorizer_with_stem = CountVectorizer(
    input='filename',
    stop_words='english',
    tokenizer=util.tokenize_and_stem,
    ngram_range=(1, 1),
#     max_features=10000,
    max_df=0.90,
    min_df=3
)

# %%
doc_term = count_vectorizer_with_stem.fit_transform(txt_files)

# %%
len(count_vectorizer_with_stem.vocabulary_)
# Out:
# 60487

# %%
count_vectorizer_with_stem.vocabulary_
# Out:
# {'depp': 13745,
#  'true': 55105,
#  'rebel': 44271,
#  'soul': 50485,
#  'cannes': 8367,
#  'director': 14378,
#  'debut': 13188,
#  'hollywood': 23929,
#  'johnny': 27341,
#  'step': 51330,
#  'camera': 8248,
#  'film': 18691,
#  'share': 48772,
#  'act': 480,
#  'honour': 24042,
#  'marlon': 32839,
#  'brando': 7062,
#  'love': 31502,
#  'story': 51550,
#  'brave': 7100,
#  'competition': 10958,
#  'festival': 18508,
#  'saturday': 47375,
#  'raphael': 43965,
#  'native': 36540,
#  'american': 1896,
#  'determine': 13932,
#  'pull': 43143,
#  'family': 18034,
#  'hovel': 24236,
#  'california': 8159,
#  'rubbish': 46378,
#  'dump': 15525,
#  'maker': 32230,
#  'underground': 55899,
#  'snuff': 50125,
#  'opportunity': 38670,
#  'price': 42483,
#  'life': 30878,
#  'promise': 42819,
#  'die': 14175,
#  'write': 59335,
#  'mind': 34531,
#  'dare': 12963,
#  'speak': 50642,
#  'role': 45999,
#  'friend': 19786,
#  'mentor': 33889,
#  'don': 15004,
#  'juan': 27502,
#  'volunteer': 57865,
#  'day': 13084,
#  'shoot': 49079,
#  'make': 32227,
#  'lot': 31453,
#  'money': 35188,
#  'catch': 8824,
#  'important': 25073,
#  'potential': 42040,
#  'seven': 48545,
#  'kentucky': 28395,
#  'bear': 5043,
#  'say': 47454,
#  'aziz': 4003,
#  'thriller': 53922,
#  'writer': 59340,
#  'gregory': 21787,
#  'mcdonald': 33433,
#  'december': 13211,
#  'kill': 28669,
#  'wife': 58797,
#  'daughter': 13037,
#  'producer': 42695,
#  'stick': 51399,
#  'project': 42780,
#  'hire': 23722,
#  'cleanse': 10231,
#  'history': 23763,
#  'past': 40059,
#  'good': 21371,
#  'send': 48311,
#  'indian': 25430,
#  'activist': 489,
#  'floyd': 19129,
#  'red': 44434,
#  'crow': 12336,
#  'perform': 40642,
#  'sunrise': 52132,
#  'ceremony': 9130,
#  'bless': 6145,
#  'remember': 44857,
#  'stifle': 51410,
#  'yellow': 59700,
#  'light': 30901,
#  'weigh': 58442,
#  'slowly': 49945,
#  'spin': 50750,
#  'score': 47836,
#  'pop': 41849,
#  'surprise': 52301,
#  'adore': 689,
#  'expensive': 17670,
#  'gift': 20910,
#  'accuse': 392,
#  'return': 45357,
#  'previous': 42454,
#  'crime': 12219,
#  'commit': 10812,
#  'institution': 25947,
#  'think': 53825,
#  'away': 3905,
#  'complete': 10981,
#  'control': 11499,
#  'set': 48508,
#  'surround': 52310,
#  'actor': 495,
#  'sense': 48341,
#  'unaware': 55735,
#  'really': 44210,
#  'fun': 19978,
#  'production': 42705,
#  'problem': 42650,
#  'pacino': 39436,
#  'dub': 15428,
#  'best': 5616,
#  'generation': 20589,
#  'know': 28968,
#  'people': 40560,
#  'like': 30919,
#  'thing': 53823,
#  'mean': 33585,
#  'obviously': 38092,
#  'great': 21724,
#  'lucky': 31611,
#  'able': 192,
#  'hero': 23477,
#  'tell': 53320,
#  'interviewer': 26167,
#  'recently': 44324,
#  'settle': 48528,
#  'los': 31447,
#  'angeles': 2233,
#  'teen': 53219,
#  'hop': 24072,
#  'career': 8523,
#  'music': 36026,
#  'meet': 33698,
#  'jury': 27653,
#  'president': 42390,
#  'sydney': 52534,
#  'pollack': 41754,
#  'discus': 14479,
#  'plan': 41427,
#  'million': 34436,
#  'graham': 21598,
#  'greene': 21745,
#  'quiet': 43501,
#  'industry': 25544,
#  'source': 50502,
#  'star': 51132,
#  'espionage': 17179,
#  'alongside': 1686,
#  'sean': 47998,
#  'connery': 11255,
#  'sign': 49342,
#  'movie': 35635,
#  'direct': 14371,
#  'phillip': 41037,
#  'noyce': 37757,
#  'brazil': 7116,
#  'month': 35291,
#  'trade': 54678,
#  'gap': 20293,
#  'bln': 6177,
#  'cni': 10398,
#  'end': 16637,
#  'march': 32650,
#  'hit': 23765,
#  'billion': 5868,
#  'accord': 359,
#  'private': 42611,
#  'national': 36518,
#  'confederation': 11154,
#  'deficit': 13369,
#  'expect': 17642,
#  'figure': 18644,
#  'sharp': 48791,
#  'contrast': 11483,
#  'record': 44402,
#  'stand': 51079,
#  'recent': 44323,
#  'change': 9330,
#  'currency': 12583,
#  'exchange': 17537,
#  'mini': 34561,
#  'band': 4452,
#  'import': 25070,
#  'finance': 18740,
#  'indicate': 25440,
#  'government': 21526,
#  'concern': 11077,
#  'reduce': 44501,
#  'simona': 49471,
#  'logu': 31318,
#  'rio': 45710,
#  'janeiro': 26896,
#  'newsroom': 37035,
#  'lamfalussy': 29941,
#  'reserve': 45139,
#  'policy': 41714,
#  'cut': 12648,
#  'burden': 7792,
#  'european': 17371,
#  'monetary': 35182,
#  'institute': 25945,
#  'emi': 16509,
#  'alexandre': 1481,
#  'friday': 19773,
#  'gradual': 21582,
#  'use': 56699,
#  'minimum': 34574,
#  'requirement': 45105,
#  'year': 59647,
#  'considerably': 11314,
#  'impose': 25078,
#  'bank': 4508,
#  'instrument': 25962,
#  'observe': 38068,
#  'evolution': 17485,
#  'technique': 53194,
#  'diminish': 14285,
#  'tax': 53099,
#  'news': 37010,
#  'conference': 11158,
#  'decline': 13256,
#  'trend': 54897,
#  'visible': 57673,
#  'reiterate': 44755,
#  'future': 20058,
#  'central': 9088,
#  'ecb': 15826,
#  'decide': 13229,
#  'adopt': 685,
#  'tool': 54457,
#  'maastricht': 31853,
#  'treaty': 54873,
#  'oblige': 38045,
#  'provide': 42962,
#  'option': 38707,
#  'bundesbank': 7760,
#  'occasion': 38102,
#  'free': 19681,
#  'security': 48130,
#  'repurchase': 45094,
#  'agreement': 1053,
#  'repos': 45033,
#  'frankfurt': 19618,
#  'baseball': 4786,
#  'monday': 35162,
#  'major': 32212,
#  'league': 30344,
#  'result': 45270,
#  'leaguebaseball': 30345,
#  'game': 20239,
#  'play': 41483,
#  'home': 23960,
#  'team': 53166,
#  'cap': 8410,
#  'boston': 6795,
#  'oakland': 37973,
#  'seattle': 48018,
#  'cleveland': 10270,
#  'milwaukee': 34506,
#  'detroit': 13950,
#  'baltimore': 4408,
#  'minnesota': 34615,
#  'anaheim': 2040,
#  'yankee': 59563,
#  'kansa': 27926,
#  'city': 10112,
#  'toronto': 54516,
#  'texas': 53551,
#  'chicago': 9676,
#  'white': 58671,
#  'sox': 50559,
#  'houston': 24230,
#  'louis': 31474,
#  'colorado': 10663,
#  'montreal': 35307,
#  'atlanta': 3492,
#  'cincinnati': 10019,
#  'san': 47082,
#  'francisco': 19588,
#  'mets': 34101,
#  'orange': 38719,
#  'county': 11946,
#  'bankruptcy': 4541,
#  'trial': 54932,
#  'juror': 27652,
#  'begin': 5174,
#  'deliberation': 13486,
#  'wednesday': 58406,
#  'relate': 44779,
#  'calif': 8156,
#  'assistant': 3339,
#  'treasurer': 54864,
#  'matthew': 33182,
#  'raabe': 43558,
#  'case': 8725,
#  'enter': 16834,
#  'final': 18712,
#  'stage': 51028,
#  'prosecutor': 42895,
#  'allege': 1591,
#  'help': 23322,
#  'divert': 14730,
#  'nearly': 36699,
#  'earn': 15737,
#  'owe': 39364,
#  'school': 47708,
#  'special': 50650,
#  'district': 14679,
#  'invest': 26265,
#  'investment': 26280,
#  'pool': 41838,
#  'fiscal': 18875,
#  'crisis': 12240,
#  'evidence': 17475,
#  'absolutely': 253,
#  'overwhelm': 39353,
#  'guilty': 22141,
#  'count': 11911,
#  'attorney': 3574,
#  'jan': 26887,
#  'nolan': 37436,
#  'close': 10331,
#  'argument': 2925,
#  'tuesday': 55234,
#  'gary': 20371,
#  'pohlson': 41653,
#  'counter': 11914,
#  'remark': 44840,
#  'person': 40761,
#  'file': 18663,
#  'sustain': 52349,
#  'loss': 31451,
#  'risky': 45736,
#  'emerge': 16497,
#  'june': 27608,
#  'indict': 25459,
#  'grand': 21628,
#  'felony': 18387,
#  'misappropriate': 34704,
#  'public': 43087,
#  'fund': 19984,
#  'fail': 17931,
#  'transfer': 54755,
#  'untrue': 56516,
#  'statement': 51179,
#  'bond': 6546,
#  'document': 14882,
#  'official': 38222,
#  'face': 17853,
#  'charge': 9395,
#  'follow': 19234,
#  'april': 2743,
#  'robert': 45852,
#  'citron': 10110,
#  'plead': 41506,
#  'judge': 27535,
#  'november': 37726,
#  'order': 38757,
#  'spend': 50714,
#  'jail': 26825,
#  'pay': 40221,
#  'fine': 18775,
#  'late': 30143,
#  'assign': 3328,
#  'community': 10854,
#  'work': 59221,
#  'program': 42754,
#  'instead': 25929,
#  'repeatedly': 44993,
#  'claim': 10145,
#  'mastermind': 33053,
#  'scheme': 47615,
#  'october': 38142,
#  'sentence': 48360,
#  'budget': 7627,
#  'ronald': 46064,
#  'rubino': 46387,
#  'probation': 42643,
#  'stem': 51318,
#  'soccer': 50154,
#  'serie': 48451,
#  'allow': 1642,
#  'non': 37457,
#  'player': 41489,
#  'italian': 26600,
#  'federation': 18318,
#  'thursday': 53977,
#  'club': 10354,
#  'union': 56191,
#  'book': 6647,
#  'season': 48008,
#  'permit': 40698,
#  'juventus': 27681,
#  'manage': 32400,
#  'antonio': 2528,
#  'reporter': 45032,
#  'divide': 14735,
#  'issue': 26575,
#  'oppose': 38673,
#  'coach': 10413,
#  'field': 18606,
#  'argue': 2923,
#  'struggle': 51730,
#  'yes': 59732,
#  'add': 544,
#  'rom': 46018,
#  'franco': 19595,
#  'sensi': 48344,
#  'intermediate': 26090,
#  'solution': 50333,
#  'include': 25226,
#  'inter': 26031,
#  'milan': 34363,
#  'line': 31014,
#  'force': 19317,
#  'sell': 48259,
#  'want': 58167,
#  'limit': 30969,
#  'entirely': 16854,
#  'abandon': 66,
#  'increasingly': 25343,
#  'hard': 22766,
#  'secure': 48090,
#  'job': 27291,
#  'outside': 39172,
#  'low': 31515,
#  'division': 14739,
#  'new': 36976,
#  'measure': 33597,
#  'compromise': 11031,
#  'period': 40659,
#  'situation': 49642,
#  'ass': 3290,
#  'buy': 7952,
#  'look': 31398,
#  'piacenza': 41124,
#  'stave': 51226,
#  'relegation': 44798,
#  'playoff': 41497,
#  'sole': 50285,
#  'employ': 16564,
#  'arouse': 3048,
#  'strong': 51708,
#  'feel': 18338,
#  'italy': 26607,
#  'senator': 48309,
#  'week': 58412,
#  'excess': 17533,
#  'prime': 42555,
#  'minister': 34583,
#  'romano': 46033,
#  'prodi': 42688,
#  'deputy': 13768,
#  'walter': 58136,
#  'veltroni': 57183,
#  'stupidity': 51787,
#  'popular': 41874,
#  'party': 39970,
#  'severino': 48561,
#  'market': 32791,
#  'blow': 6251,
#  'wide': 58752,
#  'open': 38622,
#  'grind': 21855,
#  'break': 7138,
#  'bosman': 6780,
#  'rule': 46469,
#  'movement': 35632,
#  'europe': 17370,
#  'start': 51155,
#  'increase': 25341,
#  'number': 37856,
#  'gianfranco': 20874,
#  'zola': 60395,
#  'fabrizio': 17845,
#  'ravanelli': 44100,
#  'foreign': 19347,
#  'particularly': 39951,
#  'high': 23620,
#  'english': 16730,
#  'world': 59244,
#  'govern': 21516,
#  'body': 6377,
#  'fifa': 18624,
#  'ensure': 16827,
#  'equal': 16961,
#  'treatment': 54871,
#  'finnish': 18811,
#  'economic': 15887,
#  'indicator': 25449,
#  'update': 56566,
#  'feb': 18286,
#  'schedule': 47575,
#  'gdp': 20503,
#  'statistic': 51192,
#  'finland': 18797,
#  'bof': 6402,
#  'base': 4785,
#  'rate': 44027,
#  'pct': 40261,
#  'fell': 18378,
#  'sept': 48391,
#  'tender': 53373,
#  'oct': 38136,
#  'cpi': 12054,
#  'dec': 13192,
#  'harmonise': 22843,
#  'core': 11653,
#  'inflation': 25645,
#  'mth': 35723,
#  'nov': 37713,
#  'ppi': 42123,
#  'export': 17705,
#  'wholesale': 58700,
#  'volume': 57860,
#  'retail': 45299,
#  'sale': 46913,
#  'construction': 11383,
#  'cost': 11850,
#  'industrial': 25533,
#  'output': 39151,
#  'unemployment': 56024,
#  'labour': 29774,
#  'ministrytrade': 34598,
#  'balance': 4309,
#  'ncb': 36650,
#  'estimate': 17238,
#  'blnconsumer': 6179,
#  'confidence': 11169,
#  'point': 41658,
#  'sovereign': 50539,
#  'credit': 12154,
#  'rat': 44020,
#  'standard': 51081,
#  'poor': 41844,
#  'outlook': 39127,
#  'stable': 51000,
#  'moody': 35323,
#  'january': 26934,
#  'ibca': 24615,
#  'positive': 41973,
#  'forecast': 19332,
#  'economy': 15910,
#  'min': 34518,
#  'etla': 17292,
#  'ptt': 43079,
#  'merita': 33966,
#  'oko': 38388,
#  'psp': 43045,
#  'aktia': 1298,
#  'priv': 42607,
#  'jobless': 27296,
#  'ministry': 34596,
#  'research': 45126,
#  'pellervo': 40443,
#  'okobank': 38389,
#  'postipankki': 42009,
#  'helsinki': 23331,
#  'peter': 40848,
#  'pledge': 41518,
#  'prudent': 43002,
#  'zealand': 60168,
#  'winston': 58973,
#  'responsible': 45233,
#  'social': 50171,
#  'conscience': 11279,
#  'country': 11942,
#  'afford': 846,
#  'regard': 44600,
#  'fundamental': 19986,
#  'need': 36747,
#  'parliament': 39885,
#  'certain': 9145,
#  'humanity': 24378,
#  'address': 562,
#  'bps': 6986,
#  'piece': 41164,
#  'present': 42379,
#  'release': 44793,
#  'gmt': 21194,
#  'wellington': 58494,
#  'ukraine': 55590,
#  'extend': 17736,
#  'chief': 9697,
#  'term': 53455,
#  'ukrainian': 55591,
#  'viktor': 57512,
#  'yushchenko': 59982,
#  'expire': 17680,
#  'time': 54109,
#  'vote': 57901,
#  'candidacy': 8334,
#  'appoint': 2687,
#  'head': 23092,
#  'february': 18293,
#  'grant': 21657,
#  'second': 48049,
#  'request': 45101,
#  'leonid': 30632,
#  'kuchma': 29557,
#  'win': 58908,
#  'respect': 45211,
#  'west': 58545,
#  'advocate': 767,
#  'tight': 54053,
#  'pavlo': 40208,
#  'lazarenko': 30297,
#  'despite': 13876,
#  'criticism': 12268,
#  'kiev': 28640,
#  'india': 25428,
#  'panel': 39667,
#  'review': 45415,
#  'committee': 10817,
#  'exist': 17605,
#  'procedure': 42661,
#  'study': 51767,
#  'current': 12590,
#  'law': 30256,
#  'regulation': 44663,
#  'development': 14003,
#  'mineral': 34544,
#  'suggest': 52005,
#  'delay': 13467,
#  'renewal': 44930,
#  'prospect': 42899,
#  'licence': 30826,
#  'lease': 30372,
#  'consider': 11312,
#  'delegate': 13472,
#  'power': 42093,
#  'state': 51168,
#  'check': 9519,
#  'illegal': 24859,
#  'cricket': 12209,
#  'australia': 3688,
#  'western': 58556,
#  'province': 42969,
#  'match': 33079,
#  'newlands': 36999,
#  'inning': 25812,
#  'hayden': 23056,
#  'mark': 32784,
#  'taylor': 53129,
#  'elliott': 16382,
#  'steve': 51374,
#  'waugh': 58319,
#  'kenya': 28398,
#  'opposition': 38675,
#  'court': 11971,
#  'petition': 40863,
#  'debate': 13157,
#  'daily': 12807,
#  'nation': 36516,
#  'newspaper': 37029,
#  'report': 45027,
#  'member': 33817,
#  'walk': 58097,
#  'assembly': 3307,
#  'support': 52226,
#  'suit': 52020,
#  'musalia': 36001,
#  'mudavadi': 35758,
#  'read': 44174,
#  'speaker': 50643,
#  'francis': 19586,
#  'ole': 38425,
#  'kaparo': 27949,
#  'chamber': 9272,
#  'disrupt': 14612,
#  'speech': 50685,
#  'shout': 49122,
#  'stamp': 51070,
#  'session': 48505,
#  'chaos': 9358,
#  'punch': 43162,
#  'inside': 25884,
#  'daniel': 12909,
#  'arap': 2806,
#  'moi': 35062,
#  'unprecedented': 56316,
#  'protest': 42932,
#  'stag': 51027,
#  'press': 42400,
#  'demand': 13545,
#  'sweep': 52467,
#  'constitutional': 11369,
#  'reform': 44561,
#  'ahead': 1094,
#  'presidential': 42393,
#  'parliamentary': 39887,
#  'election': 16251,
#  'presale': 42370,
#  'tennessee': 53396,
#  'hda': 23087,
#  'mln': 34892,
#  'amt': 2010,
#  'date': 13018,
#  'nyc': 37922,
#  'cusip': 12631,
#  'naissuer': 36293,
#  'house': 24216,
#  'agency': 952,
#  'tnissue': 54271,
#  'ownership': 39370,
#  'note': 37653,
#  'stat': 51167,
#  'exempt': 17573,
#  'revm': 45438,
#  'entry': 16880,
#  'yenhancements': 59716,
#  'qual': 43385,
#  'ndtd': 36687,
#  'sure': 52265,
#  'bid': 5784,
#  'ndue': 36688,
#  'mgr': 34147,
#  'cpn': 12059,
#  'dtp': 15421,
#  'ticdelivery': 54004,
#  'approx': 2724,
#  'agent': 958,
#  'memphisl': 33835,
#  'kutak': 29672,
#  'rock': 45894,
#  'atlantaf': 3493,
#  'nonelast': 37484,
#  'grid': 21817,
#  'tic': 54003,
#  'avg': 3834,
#  'bbi': 4999,
#  'rmktg': 45810,
#  'amtyear': 2014,
#  'coupon': 11958,
#  'yield': 59762,
#  'conc': 11057,
#  'competitive': 10959,
#  'pre': 42208,
#  'contribute': 11490,
#  'kenny': 28388,
#  'sheet': 48853,
#  'latvia': 30175,
#  'tough': 54595,
#  'discipline': 14439,
#  'unsustainable': 56483,
#  'imf': 24939,
#  'international': 26111,
#  'believe': 5276,
#  'latvian': 30178,
#  'continue': 11461,
#  'grip': 21862,
#  'currently': 12593,
#  'degree': 13414,
#  'expenditure': 17668,
#  'restraint': 45258,
#  'sustainable': 52351,
#  'long': 31377,
#  'representative': 45047,
#  'dimitri': 14291,
#  'demekas': 13558,
#  'reuters': 45378,
#  'interview': 26165,
#  'carry': 8671,
#  'structural': 51724,
#  'lift': 30895,
#  'revenue': 45395,
#  'enable': 16597,
#  'right': 45633,
#  'way': 58338,
#  'achieve': 416,
#  'wag': 58018,
#  'forever': 19371,
#  'scope': 47833,
#  'raise': 43765,
#  'just': 27659,
#  'collect': 10600,
#  'early': 15732,
#  'progress': 42766,
#  'area': 2889,
#  'administration': 647,
#  'actually': 501,
#  'improve': 25111,
#  'land': 29971,
#  'clear': 10233,
#  'title': 54217,
#  'facilitate': 17867,
#  'virtually': 57645,
#  'impossible': 25081,
#  'collateral': 10595,
#  'lena': 30577,
#  'torlegard': 54509,
#  'riga': 45627,
#  'british': 7318,
#  'exporter': 17708,
#  'stg': 51391,
#  'emu': 16593,
#  'batter': 4907,
#  'strength': 51649,
#  'sterling': 51356,
#  'confident': 11172,
#  'courier': 11968,
#  'company': 10871,
#  'dhl': 14091,
#  'quarterly': 43436,
#  'downturn': 15204,
#  'summer': 52080,
#  'pound': 42077,
#  'soar': 50133,
#  'rise': 45728,
#  'percent': 40582,
#  'august': 3648,
#  'push': 43249,
#  'climb': 10290,
#  'express': 17718,
#  'grave': 21693,
#  'effect': 16072,
#  'short': 49093,
#  'business': 7898,
#  'ian': 24603,
#  'campbell': 8278,
#  'general': 20574,
#  'survey': 52315,
#  'negative': 36772,
#  'impact': 25000,
#  'graphically': 21665,
#  'volatility': 57823,
#  'hurt': 24469,
#  'talk': 52841,
#  'favour': 18211,
#  'membership': 33819,
#  'single': 49539,
#  'join': 27352,
#  'large': 30080,
#  'keen': 28299,
#  'britain': 7312,
#  'small': 49977,
#  'broadly': 7355,
#  'welcome': 58477,
#  'chancellor': 9305,
#  'exchequer': 17539,
#  'gordon': 21421,
#  'brown': 7470,
#  'decision': 13239,
#  'england': 16721,
#  'independence': 25402,
#  'global': 21142,
#  'view': 57480,
#  'prefer': 42289,
#  'sooner': 50419,
#  'level': 30705,
#  'maintain': 32180,
#  'myopic': 36145,
#  'bode': 6364,
#  'perspective': 40775,
#  'main': 32166,
#  'owner': 39368,
#  'lufthansa': 31634,
#  'china': 9746,
#  'taiwan': 52770,
#  'powerful': 42098,
#  'par': 39760,
#  'south': 50510,
#  'korea': 29214,
#  'france': 19571,
#  'mike': 34340,
#  'peacock': 40347,
#  'london': 31367,
#  'worker': 59226,
#  'reject': 44761,
#  'steelmaker': 51264,
#  'clabecq': 10140,
#  'bankrupt': 4540,
#  'belgian': 5260,
#  'forge': 19380,
#  'leave': 30380,
#  'retirement': 45320,
#  'package': 39438,
#  'throw': 53937,
#  'doubt': 15139,
#  'possible': 41988,
#  'takeover': 52804,
#  'firm': 18849,
#  'cover': 12010,
#  'allocation': 1636,
#  'stock': 51455,
#  'militant': 34394,
#  'leader': 30326,
#  'roberto': 45856,
#  'orazio': 38729,
#  'pour': 42080,
#  'cold': 10564,
#  'water': 58280,
#  'pepper': 40567,
#  'trap': 54815,
#  'unanimously': 55708,
#  'clash': 10194,
#  'police': 41709,
#  'steelworker': 51266,
#  'declare': 13251,
#  'decisive': 13241,
#  'demonstration': 13611,
#  'walloon': 58125,
#  'region': 44623,
#  'majority': 32214,
#  'shareholder': 48776,
#  'forward': 19473,
#  'receiver': 44320,
#  'federal': 18309,
#  'aim': 1160,
#  'alleviate': 1611,
#  'consequence': 11297,
#  'attractive': 3578,
#  'mention': 33888,
#  'connection': 11248,
#  'buyout': 7956,
#  'steel': 51261,
#  'commodity': 10831,
#  'trader': 54689,
#  'duferco': 15466,
#  'annihilation': 2360,
#  'fountain': 19500,
#  'milky': 34411,
#  'center': 9077,
#  'discover': 14464,
#  'spurt': 50918,
#  'centre': 9099,
#  'galaxy': 20157,
#  'astronomer': 3406,
#  'explode': 17689,
#  'wind': 58912,
#  'black': 6052,
#  'hole': 23904,
#  'hot': 24181,
#  'gas': 20376,
#  'bit': 6006,
#  'matter': 33179,
#  'anti': 2474,
#  'destroy': 13899,
#  'scientist': 47806,
#  'war': 58172,
#  'particle': 39942,
#  'galactic': 20148,
#  'plain': 41417,
#  'earth': 15761,
#  'solar': 50274,
#  'reside': 45167,
#  'huge': 24345,
#  'plume': 41564,
#  'detect': 13917,
#  'hover': 24237,
#  'data': 13013,
#  'gather': 20408,
#  'orbit': 38732,
#  'compton': 11034,
#  'gamma': 20247,
#  'ray': 44119,
#  'observatory': 38067,
#  'launch': 30203,
#  'nasa': 36445,
#  'unlike': 56257,
#  'hubble': 24312,
#  'space': 50576,
#  'telescope': 53305,
#  'heavenly': 23172,
#  'phenomenon': 41006,
#  'craft': 12077,
#  'track': 54669,
#  'highly': 23629,
#  'energetic': 16675,
#  'normal': 37578,
#  'dust': 15622,
#  'heart': 23146,
#  'pack': 39437,
#  'energy': 16688,
#  'produce': 42694,
#  'collide': 10622,
#  'relatively': 44785,
#  'rare': 43987,
#  'universe': 56223,
#  'occur': 38116,
#  'wonder': 59160,
#  'fuel': 19922,
#  'come': 10718,
#  'question': 43478,
#  'symposium': 52577,
#  'williamsburg': 58868,
#  ...}

# %%
(NUM_ARTICLES, NUM_WORDS) = doc_term.shape
NUM_CATEGORIES = 5

# %%
count_vectorizer_with_stem.get_params()
# Out:
# {'analyzer': 'word',
#  'binary': False,
#  'decode_error': 'strict',
#  'dtype': numpy.int64,
#  'encoding': 'utf-8',
#  'input': 'filename',
#  'lowercase': True,
#  'max_df': 0.9,
#  'max_features': None,
#  'min_df': 3,
#  'ngram_range': (1, 1),
#  'preprocessor': None,
#  'stop_words': 'english',
#  'strip_accents': None,
#  'token_pattern': '(?u)\\b\\w\\w+\\b',
#  'tokenizer': <function __main__.tokenize_and_stem>,
#  'vocabulary': None}

# %%
term_frec = doc_term.sum(axis=0)
frec_indexes = np.asarray(term_frec.argsort())[0][::-1]

# %%
frecuent_words = np.array(count_vectorizer_with_stem.get_feature_names())[frec_indexes][:1000]
frecuent_words
# Out:
# array(['say', 'year', 'percent', 'government', 'pct', 'bank', 'new',
#        'million', 'state', 'minister', 'party', 'month', 'billion',
#        'price', 'make', 'tell', 'tax', 'trade', 'win', 'time', 'official',
#        'market', 'economic', 'president', 'week', 'country', 'plan',
#        'meet', 'election', 'union', 'expect', 'budget', 'day', 'rise',
#        'rate', 'lead', 'end', 'bond', 'foreign', 'leader', 'world',
#        'issue', 'people', 'european', 'report', 'wednesday', 'second',
#        'growth', 'change', 'central', 'house', 'late', 'tuesday', 'rat',
#        'add', 'good', 'thursday', 'point', 'high', 'national', 'finance',
#        'march', 'early', 'sale', 'rule', 'friday', 'vote', 'cut', 'monday',
#        'group', 'right', 'economy', 'policy', 'come', 'newsroom',
#        'include', 'work', 'prime', 'bln', 'company', 'inflation',
#        'political', 'leave', 'hold', 'low', 'start', 'set', 'unite',
#        'labour', 'increase', 'april', 'want', 'member', 'talk', 'fund',
#        'currency', 'far', 'deficit', 'public', 'play', 'international',
#        'city', 'need', 'china', 'jan', 'long', 'south', 'term', 'run',
#        'parliament', 'final', 'reform', 'security', 'result', 'export',
#        'general', 'game', 'opposition', 'feb', 'force', 'france', 'follow',
#        'poll', 'think', 'job', 'gdp', 'total', 'use', 'open', 'pay',
#        'january', 'law', 'germany', 'investment', 'just', 'monetary',
#        'service', 'capital', 'sunday', 'major', 'support', 'deal',
#        'unemployment', 'balance', 'team', 'june', 'business', 'match',
#        'figure', 'news', 'current', 'statement', 'help', 'economist',
#        'spend', 'strike', 'financial', 'continue', 'reserve', 'power',
#        'reuters', 'way', 'debt', 'german', 'industry', 'money', 'close',
#        'sector', 'level', 'index', 'french', 'mark', 'quarter', 'base',
#        'analyst', 'hong', 'cup', 'place', 'february', 'kong', 'remain',
#        'order', 'head', 'decision', 'clinton', 'saturday', 'britain',
#        'dollar', 'consumer', 'cost', 'worker', 'thu', 'mar', 'number',
#        'committee', 'italy', 'home', 'demand', 'apr', 'british',
#        'forecast', 'raise', 'agreement', 'allow', 'import', 'strong',
#        'ask', 'beat', 'date', 'office', 'mon', 'fall', 'nation', 'big',
#        'ministry', 'problem', 'try', 'fri', 'europe', 'look', 'note',
#        'begin', 'sign', 'december', 'school', 'stand', 'conference',
#        'lose', 'account', 'japan', 'court', 'like', 'wed', 'emu', 'face',
#        'dec', 'single', 'police', 'agree', 'return', 'coalition', 'old',
#        'chief', 'domestic', 'real', 'series', 'know', 'measure',
#        'spokesman', 'local', 'congress', 'build', 'conservative', 'data',
#        'credit', 'firm', 'accord', 'large', 'reach', 'control', 'campaign',
#        'russia', 'exchange', 'industrial', 'mln', 'offer', 'round', 'key',
#        'federal', 'period', 'record', 'join', 'deputy', 'authority',
#        'league', 'score', 'announce', 'reporter', 'centre', 'usa', 'bring',
#        'season', 'seven', 'goal', 'believe', 'oil', 'american', 'revenue',
#        'half', 'future', 'average', 'ahead', 'social', 'grow', 'victory',
#        'free', 'australia', 'source', 'product', 'war', 'share', 'likely',
#        'commission', 'indicator', 'soccer', 'player', 'agency',
#        'socialist', 'concern', 'recent', 'ago', 'seek', 'charge',
#        'council', 'release', 'minute', 'break', 'target', 'past',
#        'newspaper', 'israel', 'clear', 'hit', 'bid', 'development', 'sell',
#        'investor', 'private', 'communist', 'project', 'peace', 'july',
#        'protest', 'approve', 'county', 'hour', 'don', 'africa', 'proposal',
#        'food', 'board', 'treasury', 'main', 'fiscal', 'race', 'pressure',
#        'democratic', 'west', 'annual', 'output', 'russian', 'club', 'mean',
#        'republican', 'post', 'estimate', 'cabinet', 'question', 'india',
#        'tue', 'retail', 'department', 'form', 'great', 'decide', 'case',
#        'non', 'secretary', 'line', 'area', 'fail', 'australian', 'fight',
#        'short', 'seat', 'chairman', 'democrat', 'launch', 'action',
#        'woman', 'provide', 'majority', 'decline', 'test', 'spain', 'loan',
#        'despite', 'stock', 'senior', 'list', 'step', 'coupon', 'turn',
#        'municipal', 'reduce', 'john', 'comment', 'yield', 'best', 'york',
#        'consider', 'november', 'north', 'palestinian', 'aid', 'white',
#        'small', 'london', 'possible', 'hand', 'net', 'england', 'propose',
#        'east', 'income', 'senate', 'military', 'delay', 'fell',
#        'condition', 'position', 'television', 'director', 'jun', 'compare',
#        'effort', 'visit', 'previous', 'survey', 'yeltsin', 'little',
#        'create', 'attack', 'receive', 'process', 'warn', 'save',
#        'production', 'parliamentary', 'hop', 'region', 'pas', 'nov',
#        'italian', 'health', 'limit', 'israeli', 'view', 'claim', 'aim',
#        'drop', 'district', 'schedule', 'gold', 'cpi', 'live', 'gmt',
#        'draw', 'send', 'programme', 'division', 'human', 'approx',
#        'champion', 'chance', 'medium', 'canada', 'improve', 'championship',
#        'contract', 'african', 'appear', 'washington', 'hard', 'jpn',
#        'governor', 'important', 'euro', 'chinese', 'present', 'moody',
#        'town', 'discus', 'crisis', 'defence', 'wage', 'gross', 'act',
#        'fourth', 'gain', 'quote', 'basis', 'confidence', 'payment',
#        'czech', 'army', 'western', 'interview', 'urge', 'feed', 'tie',
#        'boost', 'car', 'monthly', 'daily', 'away', 'employment', 'thing',
#        'supply', 'surplus', 'administration', 'press', 'voter', 'mexico',
#        'speak', 'promise', 'plant', 'rebel', 'carry', 'desk', 'kill',
#        'brazil', 'candidate', 'coach', 'bad', 'today', 'treaty', 'slow',
#        'prepare', 'korea', 'value', 'book', 'ban', 'air', 'entry',
#        'effect', 'situation', 'stop', 'crown', 'risk', 'men', 'buy',
#        'earn', 'arm', 'benefit', 'accuse', 'statistic', 'maturity',
#        'cause', 'affair', 'fear', 'qualify', 'loss', 'stability',
#        'organisation', 'overall', 'life', 'family', 'republic',
#        'negotiation', 'deny', 'pound', 'radio', 'involve', 'privatisation',
#        'kohl', 'drive', 'require', 'near', 'pension', 'association',
#        'young', 'accept', 'unit', 'title', 'paris', 'push', 'special',
#        'operation', 'paper', 'night', 'defeat', 'stay', 'independent',
#        'manager', 'yen', 'man', 'executive', 'debate', 'program', 'event',
#        'suggest', 'child', 'street', 'poor', 'japanese', 'netanyahu',
#        'criterion', 'forward', 'politician', 'elect', 'role', 'opinion',
#        'assembly', 'presidential', 'ger', 'partner', 'imf', 'shoot',
#        'outside', 'finish', 'beijing', 'weekend', 'fast', 'soon', 'able',
#        'research', 'focus', 'bundesbank', 'northern', 'award', 'david',
#        'land', 'representative', 'hope', 'complete', 'activity', 'reject',
#        'institute', 'reason', 'october', 'pakistan', 'corp', 'settlement',
#        'sport', 'legal', 'construction', 'zealand', 'blair', 'sweden',
#        'civil', 'dispute', 'information', 'publish', 'summit', 'serve',
#        'legislation', 'manufacture', 'anti', 'violence', 'course', 'write',
#        'democracy', 'percentage', 'energy', 'challenge', 'michael',
#        'rally', 'bonn', 'regional', 'range', 'alliance', 'nearly', 'stage',
#        'inning', 'winner', 'moscow', 'education', 'employee', 'link',
#        'trend', 'attempt', 'ireland', 'body', 'taiwan', 'speech', 'wing',
#        'relation', 'currently', 'producer', 'affect', 'management',
#        'staff', 'oppose', 'impact', 'community', 'develop', 'ensure',
#        'waigel', 'september', 'port', 'premier', 'pledge', 'standard',
#        'lot', 'asset', 'tough', 'double', 'replace', 'threaten',
#        'movement', 'america', 'sure', 'feel', 'pact', 'maintain', 'wag',
#        'indian', 'confirm', 'hear', 'deposit', 'study', 'aaa', 'chirac',
#        'commercial', 'produce', 'cover', 'difficult', 'introduce',
#        'obligation', 'improvement', 'rival', 'subject', 'red', 'saw',
#        'probably', 'progress', 'appeal', 'favour', 'suffer', 'available',
#        'peter', 'liberal', 'tour', 'tournament', 'represent', 'review',
#        'profit', 'hospital', 'train', 'competition', 'cash', 'mobutu',
#        'fix', 'cricket', 'trillion', 'english', 'recently', 'fact', 'san',
#        'cent', 'maastricht', 'ppi', 'refuse', 'franc', 'happen',
#        'competitive', 'swiss', 'miss', 'bureau', 'chancellor', 'thousand',
#        'manage', 'worth', 'injury', 'university', 'direct', 'property',
#        'bear', 'address', 'supporter', 'province', 'road', 'prod', 'cross',
#        'performance', 'troop', 'really', 'arab', 'positive', 'welfare',
#        'session', 'ease', 'die', 'feature', 'island', 'ball', 'fra',
#        'rank', 'battle', 'albania', 'ally', 'scheme', 'turkey', 'tennis',
#        'water', 'personal', 'insurance', 'pick', 'jul', 'southern', 'weak',
#        'poland', 'arrest', 'achieve', 'matter', 'pro', 'labor', 'adjust',
#        'prevent', 'factor', 'wait', 'corruption', 'eastern', 'declare',
#        'doubt', 'block', 'fifth', 'revise', 'spanish', 'approval',
#        'extend', 'express', 'worry', 'exist', 'metre', 'draft', 'ready',
#        'lend', 'death', 'morgan', 'let', 'age', 'adj', 'cooperation',
#        'tonne', 'dutch', 'diplomat', 'negotiate', 'appoint', 'delivery',
#        'middle', 'resign', 'rest', 'pre', 'hike', 'field', 'enter',
#        'station', 'transfer', 'recovery', 'threat', 'austria', 'star',
#        'justice', 'film', 'mid', 'transport', 'vice', 'avoid', 'joint',
#        'advance', 'struggle', 'par', 'immediately', 'singapore', 'morning',
#        'border', 'zaire', 'letter', 'territory', 'seed', 'argue',
#        'reflect', 'brown', 'fuel', 'individual', 'federation', 'smith',
#        'predict', 'track', 'damage', 'issuer', 'oct', 'argentina',
#        'captain', 'century', 'drug', 'paul', 'impose', 'student',
#        'jerusalem', 'kabila', 'airline', 'apply', 'necessary', 'kim',
#        'purchase', 'august', 'king', 'trust', 'welcome', 'striker',
#        'potential', 'surprise', 'arrive', 'expert', 'pilot', 'contribute',
#        'canadian', 'chicago', 'korean', 'history', 'reduction',
#        'leadership', 'jospin', 'grant', 'institution', 'asian', 'huge',
#        'irish', 'guarantee', 'certain', 'amendment', 'telephone', 'defend',
#        'attend', 'robert', 'bulgaria', 'gap', 'expectation', 'difference',
#        'package', 'borrow', 'opportunity', 'success', 'idea', 'strength',
#        'similar', 'panel', 'tighten', 'dealer', 'park', 'independence',
#        'wicket', 'different', 'investigation', 'grind', 'texas', 'belgian',
#        'wholesale', 'black', 'asia', 'bar', 'grand', 'judge', 'sanction',
#        'career', 'mission', 'rupee', 'auction', 'ship', 'constitution',
#        'instead', 'respect', 'indicate', 'minimum', 'lack', 'commerce',
#        'operate', 'commitment', 'christian', 'global', 'refer',
#        'referendum', 'mayor', 'population', 'soviet', 'moslem', 'jewish',
#        'fly', 'collapse', 'trouble', 'motor', 'trial', 'emerge', 'expand',
#        'jean', 'throw', 'determine', 'jobless', 'request', 'penalty',
#        'announcement', 'pace', 'unlikely', 'preliminary', 'politics',
#        'decade', 'deng'],
#       dtype='<U28')

# %%
count_vectorizer_with_stem.stop_words_
# Out:
# {'tootie',
#  'marcoslm',
#  'stengths',
#  'nzgz',
#  'frx',
#  'yesdenmark',
#  'laidley',
#  'janosik',
#  'regnier',
#  'exaltation',
#  'commissionspecial',
#  'kraiem',
#  'stinnett',
#  'santam',
#  'expansionsemi',
#  'olympicism',
#  'ifri',
#  'kva',
#  'iciec',
#  'monthinterbank',
#  'arafam',
#  'futuremacquarie',
#  'flatness',
#  'adhoc',
#  'barcelone',
#  'equipmnent',
#  'pervis',
#  'catchcries',
#  'repnote',
#  'williems',
#  'montville',
#  'alderbrook',
#  'sociales',
#  'dokata',
#  'mondriaanhuis',
#  'missouriverbal',
#  'grouillard',
#  'treanor',
#  'tupolov',
#  'assaultkoen',
#  'betico',
#  'superfluously',
#  'districtorange',
#  'playdown',
#  'kennydalglish',
#  'candelaria',
#  'elkinsf',
#  'bernegger',
#  'ekalabo',
#  'henegouwen',
#  'fmaily',
#  'valiently',
#  'featherbed',
#  'tarcisio',
#  'rossetlarsson',
#  'massimilian',
#  'lundestad',
#  'moseneke',
#  'modulate',
#  'overzealously',
#  'travaill',
#  'hockeyroo',
#  'boyolali',
#  'mihalis',
#  'exner',
#  'terriffic',
#  'bisguier',
#  'toget',
#  'centraliastate',
#  'bondsbefore',
#  'vicentepromoted',
#  'projectscompetitive',
#  'corunato',
#  'tarif',
#  'poseville',
#  'byeround',
#  'wicklow',
#  'yrgdp',
#  'macdowell',
#  'paks',
#  'domesitc',
#  'mracsko',
#  'paskins',
#  'inot',
#  'pimple',
#  'wardiman',
#  'moresophisticated',
#  'goodcurrent',
#  'coury',
#  'simulatenously',
#  'lynghjem',
#  'activitiescrude',
#  'muzinga',
#  'sacrificial',
#  'vallack',
#  'millionmercedes',
#  'kresge',
#  'tonhalle',
#  'englanddavid',
#  'anmen',
#  'hesini',
#  'nyrupp',
#  'englandtennis',
#  'meinberg',
#  'australianrules',
#  'belge',
#  'iwth',
#  'bfrpct',
#  'germer',
#  'wattsonville',
#  'resigntion',
#  'redstone',
#  'ushalenko',
#  'tramcar',
#  'arbutt',
#  'himba',
#  'freethis',
#  'staller',
#  'thenfl',
#  'zhupani',
#  'sergeibabkov',
#  'socdems',
#  'aaanr',
#  'mannish',
#  'buontempo',
#  'golfon',
#  'milliman',
#  'ingrences',
#  'mucherahowa',
#  'seanorthwest',
#  'vannuchi',
#  'ramadas',
#  'soumantrade',
#  'rocchiagiani',
#  'crisisin',
#  'appearences',
#  'imrisonment',
#  'ulieru',
#  'suports',
#  'frenchtennis',
#  'gwido',
#  'talker',
#  'tubtim',
#  'abat',
#  'dandvate',
#  'omnopotence',
#  'khalturina',
#  'haroutiunian',
#  'tabbara',
#  'obigation',
#  'asssociated',
#  'bipassed',
#  'hatakeyama',
#  'promaprakorn',
#  'chronolgy',
#  'lescouflair',
#  'postsecondary',
#  'fourssemifinal',
#  'prot',
#  'groupbrett',
#  'pietraszkiewicz',
#  'flutra',
#  'fotomac',
#  'scappy',
#  'amri',
#  'critized',
#  'bucharestnotes',
#  'ludanyi',
#  'giroverband',
#  'juvet',
#  'whangarei',
#  'hkta',
#  'memorias',
#  'martires',
#  'bevo',
#  'authoritymercer',
#  'tsuchiya',
#  'lessbright',
#  'sem',
#  'solomie',
#  'pcthsbc',
#  'sysuev',
#  'jordanov',
#  'saakyan',
#  'eurepean',
#  'samaranayake',
#  'haw',
#  'mman',
#  'grishuk',
#  'annualreport',
#  'boukreev',
#  'labuthie',
#  'kobra',
#  'testamony',
#  'hypocricy',
#  'bernas',
#  'agroindustries',
#  'godophin',
#  'pernis',
#  'spendingfell',
#  'gainrobert',
#  'plage',
#  'academico',
#  'moneyif',
#  'protecters',
#  'oloffson',
#  'baluba',
#  'ponar',
#  'holender',
#  'partysls',
#  'roomy',
#  'adamcikova',
#  'secoring',
#  'dettoriowner',
#  'vakifbank',
#  'kira',
#  'taxre',
#  'worksites',
#  'fragoso',
#  'perkiomen',
#  'sadikovic',
#  'imagemovers',
#  'kypros',
#  'miokono',
#  'roett',
#  'blackwelder',
#  'hitout',
#  'indsutry',
#  'wolesaling',
#  'stinginess',
#  'longform',
#  'bethany',
#  'spinelessness',
#  'financedepartment',
#  'ruppert',
#  'debuteurobond',
#  'stongly',
#  'theywere',
#  'reveunes',
#  'kinlen',
#  'contraint',
#  'matusevich',
#  'dallasnoted',
#  'turgid',
#  'weimin',
#  'foreig',
#  'rael',
#  'windlass',
#  'nazr',
#  'offiicals',
#  'hafer',
#  'mylrea',
#  'respone',
#  'compellingly',
#  'cretin',
#  'neighboursbut',
#  'sirimangkol',
#  'meda',
#  'vapid',
#  'hibic',
#  'buyandalai',
#  'bado',
#  'asya',
#  'hkcsi',
#  'holdarchy',
#  'distibuted',
#  'tarifs',
#  'altenor',
#  'dandelot',
#  'riesen',
#  'bmoss',
#  'parle',
#  'robinmatches',
#  'andreasen',
#  'mezgebu',
#  'uneventul',
#  'darmouth',
#  'conferenceshareef',
#  'avoild',
#  'floudering',
#  'sequoyah',
#  'dewing',
#  'flandres',
#  'agelos',
#  'gneral',
#  'shoney',
#  'indicia',
#  'huffington',
#  'brothershood',
#  'bahrin',
#  'outpaceother',
#  'qara',
#  'propery',
#  'handoverbut',
#  'prieta',
#  'teimurov',
#  'hutchence',
#  'privization',
#  'confessional',
#  'vigure',
#  'kerwan',
#  'alvares',
#  'modernes',
#  'lpk',
#  'frow',
#  'budimir',
#  'dhashi',
#  'ada',
#  'rgule',
#  'exclusionmany',
#  'rbson',
#  'nitch',
#  'kurunegala',
#  'hoeller',
#  'undertakev',
#  'scorerslimoges',
#  'lovitz',
#  'lanceklusener',
#  'fcdus',
#  'orchestrator',
#  'skb',
#  'clippersseattle',
#  'kabinda',
#  'siempre',
#  'duguca',
#  'leaswood',
#  'freeskate',
#  'unocupied',
#  'thaicom',
#  'interchangeability',
#  'mjolne',
#  'pachon',
#  'nofrench',
#  'retiredthomas',
#  'successivevictories',
#  'kimsieng',
#  'hardpressed',
#  'runic',
#  'sleeman',
#  'treblinka',
#  'includeclubs',
#  'zadoinov',
#  'infrasctructure',
#  'chowdhary',
#  'subculture',
#  'eugenic',
#  'herstal',
#  'marilynn',
#  'mixeddoubles',
#  'arrowfield',
#  'askharbek',
#  'lube',
#  'jerusaelem',
#  'financian',
#  'saidpataki',
#  'surpreme',
#  'hez',
#  'langhout',
#  'brutishly',
#  'eyeliner',
#  'hapangama',
#  'nachofernandez',
#  'ethiopa',
#  'talbi',
#  'noaille',
#  'mohtar',
#  'powellism',
#  'boursier',
#  'heinsohn',
#  'assasinated',
#  'tigra',
#  'kpa',
#  'yuankang',
#  'fuit',
#  'poulaine',
#  'kruzel',
#  'repealroy',
#  'frenk',
#  'grobnik',
#  'tokto',
#  'aobut',
#  'epidemiological',
#  'simatech',
#  'dozenquantities',
#  'mytilini',
#  'gorr',
#  'marise',
#  'tirela',
#  'bennettrushed',
#  'southhampton',
#  'wasterwater',
#  'mingus',
#  'notadjusted',
#  'mobistar',
#  'goethals',
#  'buonnuome',
#  'cosultancy',
#  'gogan',
#  'bokkelsen',
#  'waybill',
#  'bungler',
#  'amitie',
#  'haolaixi',
#  'towiden',
#  'optiva',
#  'rampal',
#  'demonopolised',
#  'outrcy',
#  'sharifspeaker',
#  'raitbergerfrance',
#  'chaipo',
#  'sassunov',
#  'supermaket',
#  'pctfive',
#  'hyoun',
#  'guineastrial',
#  'munbo',
#  'christiophe',
#  'teplukhin',
#  'abdulkareem',
#  'maturitiies',
#  'tallinnsunday',
#  'heartwrenching',
#  'pointshampshire',
#  'boavistauefa',
#  'skaardalage',
#  'tanada',
#  'championshipsand',
#  'cockaded',
#  'palekar',
#  'arche',
#  'mcentee',
#  'expectedto',
#  'extrieur',
#  'monetray',
#  'vukcevic',
#  'heirachy',
#  'exerience',
#  'retuning',
#  'huantar',
#  'gauten',
#  'fgicdated',
#  'kalevi',
#  'wicketsfourth',
#  'capricorno',
#  'viligance',
#  'recio',
#  'nahuelsat',
#  'shohat',
#  'arnitez',
#  'ciudadano',
#  'inconspicuous',
#  'financethey',
#  'processat',
#  'magnificence',
#  'sampil',
#  'consharon',
#  'unocha',
#  'groundfish',
#  'arutyunyan',
#  'mechanistically',
#  'efforting',
#  'mcgruther',
#  'vunduawe',
#  'anim',
#  'chikowore',
#  'ministrymaturity',
#  'frm',
#  'bronislaw',
#  'seenpersonnel',
#  'centyral',
#  'cherkecov',
#  'schutten',
#  'fmy',
#  'ribcage',
#  'konticdeputy',
#  'zafrul',
#  'saiditaly',
#  'savinio',
#  'gainronnie',
#  'kenner',
#  'pilipino',
#  'mkontwana',
#  'oconee',
#  'dhaheri',
#  'guz',
#  'commisiosn',
#  'kamwandi',
#  'guanfu',
#  'lgc',
#  'beden',
#  'hepthatlon',
#  'frinance',
#  'computercomponents',
#  'charlottenotes',
#  'vaste',
#  'catley',
#  'rapscallion',
#  'budgt',
#  'rovira',
#  'declaredbognor',
#  'kiski',
#  'titarchuk',
#  'monod',
#  'ovaljune',
#  'peyrer',
#  'khakkulov',
#  'abliene',
#  'aubracs',
#  'weidelfield',
#  'vrace',
#  'methicillin',
#  'mussel',
#  'ofamerica',
#  'heinemann',
#  'shitless',
#  'ortakoy',
#  'tesseract',
#  'dets',
#  'tlaxcalans',
#  'sammelselg',
#  'roadworks',
#  'pointsderbyshire',
#  'apparal',
#  'realcebit',
#  'huch',
#  'declaredwindsor',
#  'apeh',
#  'arou',
#  'hairspray',
#  'jimmcgovern',
#  'atsuko',
#  'defvended',
#  'cinep',
#  'denisenko',
#  'biennual',
#  'pitillas',
#  'adal',
#  'whichended',
#  'linded',
#  'gbely',
#  'datasurface',
#  'donziais',
#  'korres',
#  'armanda',
#  'idrissi',
#  'acommitment',
#  'eqp',
#  'nikons',
#  'dyrka',
#  'stroble',
#  'reciter',
#  'mclain',
#  'tribasa',
#  'canaris',
#  'thilan',
#  'adik',
#  'martimex',
#  'advantageportugal',
#  'taube',
#  'philadelphiamilwaukee',
#  'developmentparliamentary',
#  'hemay',
#  'nonresistance',
#  'oppenraaij',
#  'portoplaying',
#  'horvaph',
#  'kessov',
#  'rogis',
#  'panmunmjom',
#  'husnu',
#  'ofdenomination',
#  'defeatedwest',
#  'fdps',
#  'mensonges',
#  'thalassaemia',
#  'dividedin',
#  'nostalgie',
#  'bitton',
#  'repave',
#  'philadelpia',
#  'carrarese',
#  'loquaciousness',
#  'panayoitis',
#  'ciculation',
#  'gallische',
#  'tartabull',
#  'yelwa',
#  'telemalta',
#  'ciri',
#  'allbombing',
#  'monterosa',
#  'turley',
#  'cameroonstriker',
#  'rupiahanother',
#  'boulat',
#  'denehurst',
#  'bolivianote',
#  'glendinning',
#  'thephiladelphia',
#  'hassall',
#  'kazenelson',
#  'novecon',
#  'vanick',
#  'borrwers',
#  'airbags',
#  'moblise',
#  'kapaz',
#  'kwt',
#  'kampini',
#  'wolter',
#  'stimorol',
#  'fabris',
#  'shazali',
#  'raden',
#  'rosler',
#  'wasmeier',
#  'stholcer',
#  'kshirsagar',
#  'kady',
#  'hennep',
#  'albufaz',
#  'ripkin',
#  'sorani',
#  'parvesh',
#  'javan',
#  'londontel',
#  'mione',
#  'changi',
#  'jre',
#  'gamzayev',
#  'eldard',
#  'telefonnaya',
#  'safarali',
#  'differnces',
#  'disunify',
#  'mlitary',
#  'lidster',
#  'bookhis',
#  'monseigneur',
#  'handscharles',
#  'agreemt',
#  'dogstar',
#  'botanic',
#  'aussems',
#  'hamacioglu',
#  'nainland',
#  'overbilled',
#  'hartsdale',
#  'yachtnew',
#  'fromaix',
#  'revollo',
#  'outputdata',
#  'threatend',
#  'katsouyanni',
#  'nsikak',
#  'bole',
#  'systemeffective',
#  'buchenwald',
#  'arcecosta',
#  'conduiting',
#  'outputit',
#  'ridger',
#  'blowin',
#  'pgk',
#  'outsiai',
#  'levswas',
#  'psq',
#  'friedland',
#  'marketeered',
#  'schoeman',
#  'compactly',
#  'oakre',
#  'meteorologie',
#  'dayyeh',
#  'megalith',
#  'rigita',
#  'algae',
#  'scrummaged',
#  'cricism',
#  'saleof',
#  'dcrating',
#  'ofsetting',
#  'iniatives',
#  'anbaa',
#  'luiot',
#  'centraldefence',
#  'bhn',
#  'zimmerbest',
#  'keeley',
#  'historywhere',
#  'sio',
#  'brickwork',
#  'couragouesfilly',
#  'pickavance',
#  'mhd',
#  'bouchouarebinterior',
#  'daghestan',
#  'teary',
#  'certi',
#  'lasee',
#  'florianmaurice',
#  'thenumber',
#  'ivanovich',
#  'beecroft',
#  'boxingcouncil',
#  'womenyuka',
#  'gijonracing',
#  'dictactorships',
#  'hopethe',
#  'dulyapinets',
#  'anglais',
#  'manufacturershave',
#  'carterton',
#  'nrdtd',
#  'monohulls',
#  'revenueimprovement',
#  'compained',
#  'efrance',
#  'kerasiotes',
#  'symonette',
#  'danniella',
#  'cheesehead',
#  'nancun',
#  'shdeid',
#  'poisic',
#  'constitutionalise',
#  'agolli',
#  'wimbldeon',
#  'bonfield',
#  'morocan',
#  'tasio',
#  'keonwook',
#  'shareownership',
#  'justham',
#  'opearational',
#  'asiasecond',
#  'qualifierradka',
#  'wagenkneht',
#  'nameto',
#  'prajya',
#  'betisstandings',
#  'ruka',
#  'februaryjob',
#  'agreementprotocol',
#  'playerwith',
#  'upvaluation',
#  'yamahas',
#  'shrewdly',
#  'bycontroversial',
#  'caledonien',
#  'couunty',
#  'togba',
#  'widereceiver',
#  'handloom',
#  'businessafter',
#  'completeredemption',
#  '___________',
#  'flakjacket',
#  'comalco',
#  'threathening',
#  'statutue',
#  'wereincreased',
#  'prignon',
#  'vrantizky',
#  'voshchanov',
#  'accep',
#  'serredszum',
#  'oesv',
#  'bran',
#  'anjclass',
#  'urbanyi',
#  'elkhart',
#  'corot',
#  'tabamkulu',
#  'mougeotte',
#  'anothai',
#  'gholamrezah',
#  'leabua',
#  'conceiveable',
#  'baranski',
#  'oestrus',
#  'betterretail',
#  'viviane',
#  'reservers',
#  'reginal',
#  'fruehwald',
#  'carmo',
#  'zairoise',
#  'gaudoin',
#  'etta',
#  'pinturichio',
#  'hitiabdul',
#  'chokachi',
#  'forc',
#  'disdainful',
#  'glowingly',
#  'mandolin',
#  'caudillos',
#  'boyz',
#  'doubtul',
#  'bienenfeld',
#  'dissipation',
#  'benicio',
#  'ligatcheva',
#  'gitin',
#  'advovacy',
#  'aggregatereal',
#  'quarterlyreport',
#  'mybotoforeign',
#  'flacid',
#  'dimakakos',
#  'ncluded',
#  'dipose',
#  'maopehealth',
#  'eurokohl',
#  'haymaker',
#  'ingetting',
#  'zani',
#  'clingan',
#  'razzmatazz',
#  'playoffssaturday',
#  'thieke',
#  'industrialties',
#  'defendingchampion',
#  'cacciari',
#  'eica',
#  'bevanfour',
#  'repal',
#  'isonomia',
#  'muncipality',
#  'prrating',
#  'declerq',
#  'rebolledo',
#  'topefer',
#  'demobiization',
#  'llyods',
#  'trento',
#  'owona',
#  'neagu',
#  'londonmarathon',
#  'petroleumsector',
#  'traddec',
#  'hissecond',
#  'arsher',
#  'sportsin',
#  'auvs',
#  'waukeshastate',
#  'illini',
#  'camaro',
#  'empereur',
#  'showd',
#  'implausibility',
#  'delli',
#  'pathetically',
#  'dorotheenbloecke',
#  'signoret',
#  'nikolaidiscroatia',
#  'improvmebnts',
#  'hasalso',
#  'geostrategic',
#  'holodov',
#  'mirvais',
#  'rahilly',
#  'antoniominnesota',
#  'borshch',
#  'vigia',
#  'problematics',
#  'shapira',
#  'depaolo',
#  'yunlocal',
#  'mecosur',
#  'sodegaard',
#  'worldtable',
#  'numberdenotesseeding',
#  'ouandaogo',
#  'belyakova',
#  'statedecu',
#  'yumin',
#  'schmuck',
#  'woltz',
#  'meeran',
#  'npv',
#  'urbancorp',
#  'schoolscounties',
#  'uhis',
#  'ordersjun',
#  'clearl',
#  'stgnation',
#  'lifestylers',
#  'cambpell',
#  'danmols',
#  'stackloads',
#  'helipad',
#  'jurong',
#  'weathervane',
#  'toovey',
#  'talyakhan',
#  'bennefits',
#  'ibtihal',
#  'unicom',
#  'pilat',
#  'scorersnacional',
#  'cheikhrural',
#  'michaelclayton',
#  'junctionl',
#  'gui',
#  'modications',
#  'nghi',
#  'agakhanovwater',
#  'bridegroom',
#  'gerp',
#  'braze',
#  'sauerkraut',
#  'conviced',
#  'formgrenoble',
#  'alcs',
#  'yearlong',
#  'ahin',
#  'cnvertibility',
#  'steffie',
#  'califanoreferee',
#  'shaqiqi',
#  'fem',
#  'suspsension',
#  'moded',
#  'laukka',
#  'diphtheria',
#  'continence',
#  'bouchouareb',
#  'goobey',
#  'haillan',
#  'barnert',
#  'kilontsi',
#  'systematise',
#  'moniroth',
#  'toler',
#  'ansolin',
#  'kabasele',
#  'rensburgclinton',
#  'parliamenty',
#  'marnote',
#  'dubashi',
#  'thlang',
#  'formanko',
#  'timperly',
#  'lemercier',
#  'sinhanoukville',
#  'wouldfollow',
#  'grenfelljeff',
#  'rud',
#  'svorcova',
#  'ouzouni',
#  'vaillancourt',
#  'affrican',
#  'scepticalretail',
#  'volfova',
#  'dunkleberger',
#  'singspielfemale',
#  'grw',
#  'tourveteran',
#  'extrajudicially',
#  'ratp',
#  'timesand',
#  'tenenbaum',
#  'triton',
#  'montrealny',
#  'herkimerl',
#  'fridleystate',
#  'cusipinformation',
#  'aigues',
#  'kots',
#  'brokens',
#  'lochhead',
#  'alast',
#  'infrastrucures',
#  'dfense',
#  'hoogma',
#  'westgerman',
#  'armandariz',
#  'bowne',
#  'ffmno',
#  'unitedborussia',
#  'bousquin',
#  'casework',
#  'cybernetics',
#  'wisit',
#  'kotaite',
#  'bunner',
#  'chakka',
#  'salif',
#  'timezones',
#  'haroutyunian',
#  'bhanuphol',
#  'holdtessa',
#  'skellett',
#  'kathyrinaldi',
#  'bronec',
#  'memoires',
#  'conomic',
#  ...}

# %%
Y = np.empty((NUM_ARTICLES, NUM_CATEGORIES))
for idx, file in enumerate(txt_files):
    Y[idx] = label_from_id(file)
np.save('y.npy', Y)

# %%
scipy.io.mmwrite('countvect-articles', doc_term)

# %%
doc_term
# Out:
# <104785x60487 sparse matrix of type '<class 'numpy.int64'>'
# 	with 10354788 stored elements in Compressed Sparse Row format>
