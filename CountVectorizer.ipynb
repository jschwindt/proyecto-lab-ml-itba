# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
import glob
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from fit_generator import label_from_id
import scipy
import util

# %%
source_path = '../converted/'

# %%
txt_files = glob.glob(source_path + '199*/*')
len(txt_files)
# Out:
# 202399

# %%
util.tokenize_and_stem("to be or not to be that 1234 2017 is the question skiing-results question question")
# Out:
# ['not', 'that', 'the', 'question', 'ski', 'result', 'question', 'question']

# %%
count_vectorizer_with_stem = CountVectorizer(
    input='filename',
    stop_words='english',
    tokenizer=util.tokenize_and_stem,
    ngram_range=(1, 1),
#     max_features=10000,
    max_df=0.90,
    min_df=3
)

# %%
doc_term = count_vectorizer_with_stem.fit_transform(txt_files)

# %%
len(count_vectorizer_with_stem.vocabulary_)
# Out:
# 84168

# %%
count_vectorizer_with_stem.vocabulary_
# Out:
# {'lukashenko': 43822,
#  'stir': 71505,
#  'crowd': 17221,
#  'talk': 73476,
#  'chernobyl': 13486,
#  'president': 59040,
#  'alexander': 2133,
#  'face': 24683,
#  'chorus': 13847,
#  'criticism': 17128,
#  'abroad': 371,
#  'turn': 77045,
#  'people': 56530,
#  'ecstatic': 22101,
#  'tuesday': 76890,
#  'exploit': 24481,
#  'painful': 55063,
#  'memory': 46933,
#  'belarus': 7451,
#  'world': 82404,
#  'war': 80936,
#  'nuclear': 52629,
#  'disaster': 20113,
#  'unite': 78213,
#  'state': 71115,
#  'european': 24052,
#  'official': 53191,
#  'russia': 64700,
#  'ukraine': 77384,
#  'express': 24513,
#  'concern': 15514,
#  'constitutional': 15909,
#  'row': 64336,
#  'pit': 57616,
#  'parliament': 55565,
#  'institution': 35717,
#  'year': 82953,
#  'old': 53491,
#  'leader': 41955,
#  'support': 72603,
#  'dear': 18366,
#  'referendum': 62019,
#  'november': 52473,
#  'vote': 80552,
#  'live': 43119,
#  'future': 27632,
#  'child': 13644,
#  'say': 66031,
#  'seek': 67008,
#  'approval': 3896,
#  'new': 51398,
#  'draft': 21159,
#  'extend': 24535,
#  'term': 74342,
#  'tighten': 75236,
#  'grip': 30115,
#  'branch': 10007,
#  'power': 58643,
#  'deputy': 19236,
#  'join': 37652,
#  'force': 26634,
#  'stop': 71611,
#  'enforce': 23118,
#  'result': 62974,
#  'carry': 12205,
#  'legal': 42147,
#  'despite': 19388,
#  'court': 16743,
#  'rule': 64584,
#  'speed': 70476,
#  'small': 69521,
#  'military': 47727,
#  'town': 76072,
#  'mile': 47687,
#  'east': 21903,
#  'minsk': 48056,
#  'big': 8259,
#  'black': 8622,
#  'mercedes': 47047,
#  'head': 31856,
#  'impressive': 34616,
#  'motorcade': 49327,
#  'western': 81466,
#  'build': 10842,
#  'vehicle': 79512,
#  'lock': 43274,
#  'know': 40027,
#  'supreme': 72626,
#  'soviet': 70309,
#  'address': 811,
#  'foot': 26592,
#  'huge': 33594,
#  'monument': 49007,
#  'vladimir': 80350,
#  'lenin': 42333,
#  'emblazon': 22834,
#  'word': 82370,
#  'invoke': 36173,
#  'nazi': 50875,
#  'overrun': 54777,
#  'country': 16704,
#  'poland': 58092,
#  'fight': 25719,
#  'till': 75288,
#  'bury': 11111,
#  'person': 56809,
#  'come': 15037,
#  'declare': 18503,
#  'belarussians': 7457,
#  'tell': 74164,
#  'horror': 33295,
#  'story': 71647,
#  'relative': 62336,
#  'slaughter': 69334,
#  'occupation': 53019,
#  'adolf': 972,
#  'hitler': 32807,
#  'explosion': 24490,
#  'plant': 57752,
#  'upset': 78747,
#  'refer': 62016,
#  'question': 60529,
#  'propose': 59683,
#  'buy': 11213,
#  'sell': 67149,
#  'land': 41467,
#  'privatisation': 59336,
#  'quarter': 60465,
#  'republic': 62736,
#  'territory': 74388,
#  'contaminate': 15988,
#  'percent': 56565,
#  'fallout': 24879,
#  'reactor': 61530,
#  'hit': 32794,
#  'affect': 1165,
#  'thousand': 75017,
#  'opponent': 53879,
#  'home': 33077,
#  'accuse': 570,
#  'dictatorship': 19776,
#  'begin': 7363,
#  'tour': 76035,
#  'draw': 21223,
#  'fear': 25242,
#  'fascism': 25059,
#  'return': 63075,
#  'interrupt': 35971,
#  'minute': 48078,
#  'speech': 70472,
#  'time': 75317,
#  'rapturous': 61236,
#  'applause': 3830,
#  'hurrah': 33747,
#  'life': 42726,
#  'promise': 59613,
#  'right': 63459,
#  'criticise': 17126,
#  'strike': 71813,
#  'beat': 7205,
#  'elderly': 22532,
#  'overwhelm': 54837,
#  'appearance': 3804,
#  'lean': 42007,
#  'angular': 3288,
#  'moustachioed': 49424,
#  'batska': 6973,
#  'belarussian': 7456,
#  'father': 25099,
#  'nikolai': 51807,
#  'pensioner': 56506,
#  'greasy': 29941,
#  'brown': 10550,
#  'raincoat': 60920,
#  'explain': 24470,
#  'great': 29942,
#  'man': 44892,
#  'speak': 70425,
#  'really': 61574,
#  'like': 42783,
#  'simply': 68868,
#  'clearly': 14372,
#  'wave': 81156,
#  'red': 61877,
#  'green': 29961,
#  'flag': 26169,
#  'veteran': 79803,
#  'union': 78184,
#  'bloody': 8884,
#  'prolong': 59597,
#  'afghanistan': 1202,
#  'warm': 80971,
#  'concert': 15515,
#  'song': 70073,
#  'apparently': 3798,
#  'sack': 64936,
#  'resign': 62846,
#  'include': 34779,
#  'prime': 59252,
#  'minister': 47981,
#  'monday': 48788,
#  'rat': 61290,
#  'abandon': 104,
#  'ship': 68205,
#  'sink': 68978,
#  'sail': 65122,
#  'surely': 72664,
#  'bright': 10289,
#  'concept': 15509,
#  'cornerstone': 16348,
#  'ideology': 34077,
#  'era': 23512,
#  'impoverish': 34598,
#  'nostalgia': 52357,
#  'georgian': 28485,
#  'aide': 1635,
#  'condemn': 15572,
#  'death': 18371,
#  'supporter': 72606,
#  'late': 41712,
#  'zviad': 84139,
#  'gamsakhurdia': 27901,
#  'scuffle': 66691,
#  'police': 58120,
#  'sentence': 67287,
#  'close': 14503,
#  'associate': 4793,
#  'depose': 19192,
#  'loti': 43535,
#  'lead': 41952,
#  'rebel': 61651,
#  'civil': 14223,
#  'oust': 54484,
#  'nationalist': 50727,
#  'try': 76754,
#  'retake': 63009,
#  'eduard': 22226,
#  'shevardnadze': 68111,
#  'guilty': 30487,
#  'treason': 76378,
#  'murder': 49915,
#  'defendant': 18630,
#  'sing': 68913,
#  'defiance': 18650,
#  'judge': 37891,
#  'georgia': 28479,
#  'execute': 24313,
#  'style': 71978,
#  'single': 68945,
#  'bullet': 10898,
#  'execution': 24314,
#  'chief': 13617,
#  'bodyguard': 9076,
#  'member': 46910,
#  'nugzar': 52646,
#  'prison': 59315,
#  'range': 61153,
#  'die': 19794,
#  'break': 10119,
#  'protester': 59759,
#  'hold': 32977,
#  'candlelight': 11754,
#  'vigil': 79972,
#  'outside': 54595,
#  'dozen': 21134,
#  'demonstrator': 19028,
#  'shout': 68381,
#  'junta': 38027,
#  'placard': 57694,
#  'bear': 7188,
#  'portrait': 58437,
#  'jostle': 37789,
#  'disperse': 20304,
#  'arrest': 4397,
#  'report': 62662,
#  'dress': 21270,
#  'national': 50718,
#  'costume': 16597,
#  'read': 61531,
#  'applaud': 3829,
#  'sarcastically': 65752,
#  'penalty': 56408,
#  'announce': 3417,
#  'rendition': 62500,
#  'folk': 26521,
#  'ballad': 6218,
#  'plead': 57842,
#  'innocent': 35557,
#  'charge': 13208,
#  'conflict': 15667,
#  'journalist': 37804,
#  'dato': 18189,
#  'cameraman': 11630,
#  'worldwide': 82423,
#  'television': 74155,
#  'news': 51443,
#  'kill': 39593,
#  'pump': 60063,
#  'chest': 13518,
#  'kalashnikov': 38270,
#  'automatic': 5380,
#  'rifle': 63447,
#  'eccentric': 21974,
#  'ride': 63407,
#  'credential': 16967,
#  'dissident': 20367,
#  'win': 81961,
#  'presidential': 59043,
#  'election': 22552,
#  'topple': 75864,
#  'january': 37053,
#  'claim': 14247,
#  'dictator': 19774,
#  'week': 81267,
#  'leave': 42037,
#  'centre': 12787,
#  'capital': 11871,
#  'tbilisi': 73906,
#  'ruin': 64572,
#  'flee': 26248,
#  'foreign': 26674,
#  'native': 50749,
#  'launch': 41785,
#  'uprise': 78742,
#  'aim': 1658,
#  'claw': 14346,
#  'army': 4329,
#  'rout': 64321,
#  'separatist': 67314,
#  'sea': 66729,
#  'region': 62130,
#  'abkhazia': 298,
#  'bread': 10114,
#  'truck': 76695,
#  'driver': 21304,
#  'string': 71819,
#  'pro': 59369,
#  'victory': 79909,
#  'russian': 64701,
#  'aid': 1629,
#  'help': 32163,
#  'save': 65971,
#  'mysteriously': 50195,
#  'fanatic': 24927,
#  'believe': 7507,
#  'alive': 2258,
#  'defend': 18628,
#  'continue': 16031,
#  'use': 78866,
#  'international': 35927,
#  'pressure': 59064,
#  'note': 52371,
#  'currently': 17569,
#  'polish': 58144,
#  'low': 43630,
#  'house': 33414,
#  'tax': 73849,
#  'thursday': 75135,
#  'likely': 42788,
#  'discus': 20183,
#  'upper': 78731,
#  'amendment': 2709,
#  'wednesday': 81259,
#  'parliamentary': 55567,
#  'press': 59055,
#  'office': 53186,
#  'schedule': 66209,
#  'suggest': 72274,
#  'presidium': 59048,
#  'change': 13116,
#  'set': 67507,
#  'agenda': 1374,
#  'start': 71098,
#  'session': 67501,
#  'gmt': 29193,
#  'senate': 67220,
#  'pas': 55731,
#  'sejm': 67091,
#  'introduce': 36063,
#  'personal': 56813,
#  'income': 34794,
#  'level': 42493,
#  'instead': 35697,
#  'reject': 62312,
#  'simple': 68861,
#  'majority': 44604,
#  'present': 59026,
#  'warsaw': 81000,
#  'newsroom': 51477,
#  'city': 14202,
#  'san': 65483,
#  'antonio': 3617,
#  'texas': 74483,
#  'mln': 48422,
#  'repriced': 62699,
#  'texasre': 74492,
#  'taxable': 73852,
#  'obligation': 52913,
#  'general': 28348,
#  'improvement': 34632,
#  'refund': 62073,
#  'bond': 9296,
#  'series': 67425,
#  'moody': 49020,
#  'fitch': 26102,
#  'aadated': 30,
#  'coupon': 16726,
#  'maturity': 46041,
#  'price': 59159,
#  'approx': 3901,
#  'information': 35366,
#  'treasury': 76383,
#  'spread': 70719,
#  'yield': 83108,
#  'feature': 25261,
#  'fund': 27528,
#  'combination': 15030,
#  'revenue': 63126,
#  'certificate': 12862,
#  'bmoody': 8954,
#  'award': 5564,
#  'expect': 24418,
#  'delivery': 18861,
#  'december': 18451,
#  'southwest': 70287,
#  'companypainewebber': 15294,
#  'incorporatedprincipal': 34901,
#  'financial': 25882,
#  'security': 66962,
#  'municipal': 49855,
#  'desk': 19365,
#  'brazil': 10094,
#  'reform': 62049,
#  'brazilian': 10096,
#  'fernando': 25479,
#  'henrique': 32261,
#  'cardoso': 12003,
#  'rural': 64668,
#  'unequal': 77981,
#  'distribution': 20420,
#  'problem': 59388,
#  'decree': 18544,
#  'approve': 3899,
#  'congress': 15711,
#  'effect': 22293,
#  'soon': 70112,
#  'publish': 59986,
#  'government': 29681,
#  'gazette': 28215,
#  'mainly': 44547,
#  'landowner': 41498,
#  'unproductive': 78379,
#  'property': 59664,
#  'pay': 56026,
#  'annual': 3427,
#  'value': 79206,
#  'collection': 14872,
#  'rigorous': 63484,
#  'case': 12272,
#  'large': 41625,
#  'landholding': 41483,
#  'evasion': 24131,
#  'occur': 53023,
#  'type': 77196,
#  'weekly': 81277,
#  'radio': 60759,
#  'broadcast': 10390,
#  'hour': 33405,
#  'measure': 46597,
#  'send': 67225,
#  'proposal': 59680,
#  'page': 55021,
#  'history': 32790,
#  'injustice': 35513,
#  'bad': 5905,
#  'concentration': 15504,
#  'add': 790,
#  'productive': 59472,
#  'hectare': 31986,
#  'make': 44629,
#  'consider': 15834,
#  'owner': 54860,
#  'confiscate': 15664,
#  'agrarian': 1494,
#  'program': 59537,
#  'eighty': 22411,
#  'farm': 25008,
#  'belong': 7564,
#  'population': 58357,
#  'average': 5468,
#  'accord': 530,
#  'catholic': 12447,
#  'church': 13985,
#  'commission': 15145,
#  'cpt': 16862,
#  'blame': 8679,
#  'situation': 69098,
#  'increase': 34939,
#  'number': 52663,
#  'landless': 41486,
#  'peasant': 56253,
#  'dead': 18333,
#  'operation': 53839,
#  'remove': 62462,
#  'squatter': 70796,
#  'movement': 49442,
#  'mst': 49553,
#  'pursue': 60165,
#  'active': 706,
#  'campaign': 11663,
#  'recover': 61845,
#  'estimate': 23857,
#  'million': 47772,
#  'family': 24919,
#  'lukewarm': 43826,
#  'welcome': 81357,
#  'sympathize': 73081,
#  'main': 44533,
#  'agriculture': 1520,
#  'coordinator': 16211,
#  'francisco': 27006,
#  'reuters': 63099,
#  'important': 34582,
#  'issue': 36545,
#  'decision': 18486,
#  'collect': 14870,
#  'commit': 15154,
#  'response': 62912,
#  'demand': 18914,
#  'worker': 82382,
#  'farmer': 25009,
#  'employer': 22955,
#  'employee': 22951,
#  'association': 4807,
#  'raul': 61389,
#  'receipt': 61714,
#  'billion': 8342,
#  'money': 48823,
#  'directly': 20061,
#  'soccer': 69758,
#  'emerson': 22869,
#  'riverside': 63656,
#  'middlesbrough': 47519,
#  'manager': 44903,
#  'bryan': 10641,
#  'robson': 63776,
#  'midfielder': 47531,
#  'remain': 62394,
#  'club': 14534,
#  'england': 23151,
#  'saturday': 65912,
#  'holiday': 32993,
#  'train': 76180,
#  'rest': 62931,
#  'team': 73945,
#  'stadium': 70910,
#  'stay': 71209,
#  'teethe': 74027,
#  'sort': 70168,
#  'thing': 74919,
#  'player': 57817,
#  'slip': 69423,
#  'table': 73232,
#  'point': 58044,
#  'seven': 67561,
#  'game': 27883,
#  'anxious': 3662,
#  'controversy': 16096,
#  'concentrate': 15503,
#  'match': 45869,
#  'champion': 13058,
#  'manchester': 44937,
#  'suspend': 72766,
#  'clash': 14311,
#  'available': 5428,
#  'league': 41982,
#  'cup': 17484,
#  'tie': 75193,
#  'newcastle': 51413,
#  'fly': 26429,
#  'ago': 1445,
#  'amid': 2755,
#  'wife': 81805,
#  'homesick': 33109,
#  'chile': 13656,
#  'entry': 23353,
#  'nafta': 50318,
#  'priority': 59304,
#  'clinton': 14469,
#  'north': 52293,
#  'american': 2717,
#  'free': 27128,
#  'trade': 76131,
#  'agreement': 1503,
#  'white': 81629,
#  'speedy': 70484,
#  'congressional': 15712,
#  'inclusion': 34785,
#  'pact': 54964,
#  'senior': 67247,
#  'counselor': 16654,
#  'thomas': 74964,
#  'mclarty': 46486,
#  'refuse': 62088,
#  'speculate': 70466,
#  'quickly': 60549,
#  'grant': 29859,
#  'fast': 25077,
#  'track': 76119,
#  'hope': 33219,
#  'forward': 26842,
#  'timely': 75336,
#  'manner': 45073,
#  'administration': 928,
#  'consulations': 15951,
#  'conference': 15630,
#  'canada': 11702,
#  'mexico': 47328,
#  'sign': 68686,
#  'early': 21845,
#  'follow': 26527,
#  'negotiation': 51117,
#  'george': 28472,
#  'bush': 11123,
#  'earmark': 21848,
#  'attempt': 5080,
#  'stymie': 71983,
#  'opposition': 53892,
#  'negative': 51092,
#  'mexican': 47324,
#  'crisis': 17085,
#  'erupt': 23666,
#  'outlook': 54538,
#  'membership': 46912,
#  'distant': 20382,
#  'today': 75592,
#  'sense': 67265,
#  'optimism': 53928,
#  'latin': 41733,
#  'america': 2716,
#  'praise': 58737,
#  'emerge': 22862,
#  'democracy': 18985,
#  'nation': 50716,
#  'stride': 71808,
#  'improve': 34631,
#  'socio': 69799,
#  'economic': 22049,
#  'condition': 15586,
#  'chilean': 13657,
#  'fair': 24790,
#  'federal': 25292,
#  'budget': 10767,
#  'devote': 19596,
#  'social': 69781,
#  'leg': 42145,
#  'argentina': 4180,
#  'uruguay': 78840,
#  'jam': 36947,
#  'craig': 16885,
#  'sao': 65688,
#  'paulo': 55964,
#  'saddam': 64970,
#  'officer': 53188,
#  'iraqi': 36278,
#  'hussein': 33779,
#  'decorate': 18533,
#  'bravery': 10078,
#  'commander': 15090,
#  'alongside': 2431,
#  'kurdish': 40985,
#  'faction': 24725,
#  'rival': 63632,
#  'group': 30216,
#  'august': 5207,
#  'newspaper': 51468,
#  'run': 64615,
#  'televison': 74156,
#  'defence': 18623,
#  'sultan': 72359,
#  'hashim': 31630,
#  'ahmed': 1591,
#  'son': 70056,
#  'republican': 62739,
#  'guard': 30367,
#  'supervisor': 72574,
#  'distinguish': 20401,
#  'role': 63946,
#  'kurdistan': 40986,
#  'democratic': 18991,
#  'party': 55681,
#  'kdp': 38965,
#  'capture': 11928,
#  'northern': 52312,
#  'arbil': 4049,
#  'mention': 47013,
#  'cooperation': 16203,
#  'baghdad': 5984,
#  'lash': 41679,
#  'patriotic': 55908,
#  'puk': 60027,
#  'iraq': 36277,
#  'favour': 25164,
#  'zionism': 83955,
#  'israel': 36525,
#  'iran': 36274,
#  'quote': 60627,
#  'reference': 62018,
#  'jalal': 36932,
#  'talabani': 73448,
#  'urge': 78812,
#  'aside': 4644,
#  'difference': 19830,
#  'wish': 82100,
#  'deviation': 19571,
#  'homeland': 33092,
#  'wash': 81023,
#  'shameless': 67810,
#  'stand': 70996,
#  'retaliatory': 63012,
#  'missile': 48265,
#  'southern': 70269,
#  'oppose': 53889,
#  'involvement': 36177,
#  'just': 38074,
#  'want': 80926,
#  'aggression': 1400,
#  'day': 18266,
#  'sponsor': 70657,
#  'round': 64281,
#  'peace': 56223,
#  'agree': 1497,
#  'ceasefire': 12612,
#  'effort': 22314,
#  'sport': 70678,
#  'doig': 20738,
#  'dismiss': 20266,
#  'ball': 6217,
#  'tamper': 73550,
#  'suggestion': 72275,
#  'auckland': 5158,
#  'nov': 52454,
#  'zealand': 83675,
#  'cricket': 17048,
#  'executive': 24316,
#  'christopher': 13906,
#  'medium': 46704,
#  'bowler': 9866,
#  'simon': 68852,
#  'doull': 21054,
#  'pakistan': 55094,
#  'nzpa': 52815,
#  'lahore': 41309,
#  'base': 6828,
#  'photograph': 57258,
#  'yesterday': 83077,
#  'caption': 11921,
#  'nail': 50383,
#  'thumb': 75104,
#  'disfigure': 20206,
#  'ask': 4657,
#  'icc': 33994,
#  'referee': 62017,
#  'action': 700,
#  'management': 44901,
#  'satisfy': 65886,
#  'involve': 36176,
#  'sinister': 68976,
#  'activity': 714,
#  'picture': 57352,
#  'earle': 21835,
#  'cooper': 16200,
#  'assure': 4829,
#  'assume': 4824,
#  'entirely': 23319,
#  'mischievous': 48172,
#  'clean': 14355,
#  'dirt': 20077,
#  'cricketer': 17050,
#  'cheat': 13351,
#  'raise': 60935,
#  'practice': 58707,
#  'grind': 30107,
#  'sandy': 65570,
#  'cling': 14456,
#  'wasn': 81053,
#  'surprise': 72709,
#  'incident': 34763,
#  'happy': 31351,
#  'disappoint': 20099,
#  'mind': 47912,
#  'happen': 31346,
#  'overly': 54741,
#  'ironic': 36334,
#  'recent': 61729,
#  'scrutiny': 66681,
#  'similar': 68832,
#  'captain': 11915,
#  'outspoken': 54608,
#  'ken': 39092,
#  'rutherford': 64729,
#  'south': 70254,
#  'africa': 1246,
#  'secretary': 66869,
#  'arrive': 4411,
#  'china': 13685,
#  'warren': 80991,
#  'beijing': 7409,
#  'high': 32586,
#  'visit': 80242,
#  'mix': 48364,
#  'signal': 68688,
#  'arrival': 4410,
#  'combine': 15031,
#  'toughness': 76026,
#  'conciliation': 15532,
#  'tangle': 73590,
#  'sino': 68987,
#  'relation': 62332,
#  'strain': 71697,
#  'dispute': 20329,
#  'human': 33633,
#  'arm': 4287,
#  'proliferation': 59594,
#  'taiwan': 73373,
#  'contact': 15977,
#  'month': 48966,
#  'ahead': 1568,
#  'boil': 9173,
#  'confer': 15627,
#  'jiang': 37445,
#  'zemin': 83750,
#  'manila': 45041,
#  'sideline': 68597,
#  'asia': 4635,
#  'pacific': 54948,
#  'summit': 72390,
#  'plan': 57733,
#  'discussion': 20187,
#  'exchange': 24274,
#  'scottish': 66609,
#  'division': 20497,
#  'partick': 55648,
#  'johnstone': 37645,
#  'postpone': 58539,
#  'fife': 25709,
#  'greenock': 29980,
#  'morton': 49209,
#  'rtrs': 64445,
#  'slack': 69298,
#  'import': 34579,
#  'dent': 19121,
#  'australia': 5271,
#  'investment': 36145,
#  'hop': 33217,
#  'australian': 5275,
#  'merchandise': 47052,
#  'figure': 25735,
#  'release': 62347,
#  'provide': 59796,
#  'far': 24961,
#  'evidence': 24195,
#  'subdue': 72025,
#  'economy': 22076,
#  'policy': 58128,
#  'maker': 44636,
#  'upbeat': 78692,
#  'forecast': 26652,
#  'business': 11139,
#  'little': 43100,
#  'optimistic': 53930,
#  'rise': 63585,
#  'overall': 54658,
#  'line': 42907,
#  'market': 45455,
#  'good': 29461,
#  'machinery': 44160,
#  'slide': 69398,
#  'han': 31185,
#  'kunnen': 40960,
#  'economist': 22068,
#  'colonial': 14948,
#  'bank': 6434,
#  'data': 18166,
#  'confirm': 15658,
#  'lack': 41211,
#  'confidence': 15644,
#  'spend': 70508,
#  'invest': 36125,
#  'fall': 24864,
#  'october': 53061,
#  'wipe': 82056,
#  'gain': 27742,
#  'previous': 59121,
#  'mean': 46577,
#  'fiscal': 26063,
#  'period': 56668,
#  'matter': 46012,
#  'assessment': 4760,
#  'chunk': 13976,
#  'equipment': 23495,
#  'look': 43453,
#  'setback': 67510,
#  'clear': 14363,
#  'expenditure': 24454,
#  'matthew': 46016,
#  'drennan': 21265,
#  'axiom': 5610,
#  'reserve': 62805,
#  'highlight': 32595,
#  'linchpin': 42878,
#  'growth': 30250,
#  'quarterly': 60470,
#  'review': 63155,
#  'analyst': 2940,
#  'reckon': 61771,
#  'impression': 34611,
#  'soften': 69861,
#  'intention': 35817,
#  'ease': 21895,
#  'monetary': 48813,
#  'significantly': 68703,
#  'strengthen': 71786,
#  'think': 74922,
#  'airtight': 1725,
#  'stimulus': 71491,
#  'require': 62761,
#  'cut': 17634,
#  'caution': 12492,
#  'downgrade': 21096,
#  'structure': 71880,
#  'sensitive': 67276,
#  'paint': 55070,
#  'pocket': 57989,
#  'strength': 71785,
#  'weakness': 81215,
#  'consumption': 15971,
#  'fell': 25388,
#  'seasonally': 66788,
#  'adjust': 905,
#  'september': 67335,
#  'seasonal': 66786,
#  'adjustment': 910,
#  'quite': 60611,
#  'significant': 68702,
#  'original': 54144,
#  'intermediate': 35902,
#  'catch': 12413,
#  'plastic': 57774,
#  'paper': 55379,
#  'largely': 41626,
#  'jump': 37978,
#  'fuel': 27445,
#  'balance': 6148,
#  'payment': 56039,
#  'perspective': 56825,
#  'deficit': 18658,
#  'surprisingly': 72710,
#  'imply': 34574,
#  'stephen': 71370,
#  'robert': 63747,
#  'ubs': 77263,
#  'mild': 47682,
#  'deterioration': 19451,
#  'warn': 80977,
#  'potential': 58572,
#  'current': 17566,
#  'account': 538,
#  'sydney': 73033,
#  'argentine': 4181,
#  'fiel': 25683,
#  'gdp': 28258,
#  'pct': 56077,
#  'daily': 17864,
#  'abel': 247,
#  'private': 59329,
#  'consult': 15952,
#  'predict': 58865,
#  'fourth': 26904,
#  'interview': 35992,
#  'ambito': 2660,
#  'financiero': 25895,
#  'gross': 30180,
#  'domestic': 20797,
#  'product': 59459,
#  'compare': 15322,
#  'provisional': 59809,
#  'anticipate': 3553,
#  'slump': 69503,
#  'engine': 23143,
#  'construction': 15932,
#  'auto': 5358,
#  'sector': 66883,
#  'post': 58509,
#  'cycle': 17693,
#  'solid': 69950,
#  'export': 24499,
#  'drive': 21303,
#  'comment': 15109,
#  'grow': 30245,
#  ...}

# %%
(NUM_ARTICLES, NUM_WORDS) = doc_term.shape

# %%
count_vectorizer_with_stem.get_params()
# Out:
# {'analyzer': 'word',
#  'binary': False,
#  'decode_error': 'strict',
#  'dtype': numpy.int64,
#  'encoding': 'utf-8',
#  'input': 'filename',
#  'lowercase': True,
#  'max_df': 0.9,
#  'max_features': None,
#  'min_df': 3,
#  'ngram_range': (1, 1),
#  'preprocessor': None,
#  'stop_words': 'english',
#  'strip_accents': None,
#  'token_pattern': '(?u)\\b\\w\\w+\\b',
#  'tokenizer': <function util.tokenize_and_stem>,
#  'vocabulary': None}

# %%
term_frec = doc_term.sum(axis=0)
frec_indexes = np.asarray(term_frec.argsort())[0][::-1]

# %%
frecuent_words = np.array(count_vectorizer_with_stem.get_feature_names())[frec_indexes][:1000]
frecuent_words
# Out:
# array(['say', 'year', 'percent', 'government', 'pct', 'bank', 'new',
#        'million', 'state', 'minister', 'month', 'party', 'price',
#        'billion', 'make', 'tell', 'trade', 'official', 'time', 'tax',
#        'win', 'president', 'economic', 'week', 'market', 'country', 'meet',
#        'union', 'plan', 'election', 'expect', 'rate', 'budget', 'day',
#        'rise', 'end', 'bond', 'lead', 'foreign', 'issue', 'world',
#        'people', 'leader', 'wednesday', 'second', 'growth', 'change',
#        'report', 'tuesday', 'rat', 'european', 'central', 'late', 'house',
#        'good', 'early', 'thursday', 'national', 'high', 'sale', 'add',
#        'cut', 'point', 'vote', 'rule', 'bln', 'finance', 'economy',
#        'friday', 'monday', 'group', 'newsroom', 'inflation', 'include',
#        'come', 'work', 'company', 'policy', 'right', 'prime', 'low',
#        'hold', 'political', 'member', 'increase', 'talk', 'set', 'leave',
#        'unite', 'start', 'international', 'currency', 'want', 'deficit',
#        'far', 'fund', 'public', 'need', 'term', 'city', 'june', 'long',
#        'play', 'run', 'security', 'general', 'labour', 'result', 'export',
#        'parliament', 'final', 'south', 'force', 'gdp', 'total', 'follow',
#        'open', 'poll', 'pay', 'march', 'reform', 'use', 'china', 'think',
#        'july', 'clinton', 'opposition', 'service', 'strike', 'game',
#        'investment', 'just', 'law', 'balance', 'deal', 'job', 'monetary',
#        'business', 'news', 'economist', 'figure', 'sunday', 'support',
#        'current', 'capital', 'spend', 'france', 'help', 'statement',
#        'continue', 'power', 'debt', 'reserve', 'team', 'unemployment',
#        'reuters', 'close', 'sector', 'industry', 'major', 'index',
#        'financial', 'match', 'base', 'level', 'way', 'germany', 'money',
#        'order', 'consumer', 'analyst', 'quarter', 'worker', 'jan', 'april',
#        'forecast', 'mark', 'remain', 'german', 'thu', 'cost', 'agreement',
#        'head', 'fri', 'home', 'saturday', 'decision', 'number', 'dollar',
#        'place', 'allow', 'date', 'demand', 'sign', 'ministry', 'import',
#        'french', 'strong', 'cup', 'nation', 'fall', 'mon', 'big',
#        'conference', 'try', 'problem', 'nov', 'ask', 'january', 'office',
#        'raise', 'committee', 'account', 'british', 'lose', 'oct',
#        'britain', 'begin', 'note', 'court', 'look', 'return', 'chief',
#        'japan', 'dec', 'italy', 'like', 'old', 'beat', 'wed', 'agree',
#        'industrial', 'local', 'stand', 'oil', 'police', 'school',
#        'domestic', 'hong', 'face', 'europe', 'mln', 'kong', 'series',
#        'measure', 'december', 'control', 'single', 'exchange', 'spokesman',
#        'campaign', 'real', 'know', 'firm', 'data', 'accord', 'large',
#        'aug', 'half', 'reach', 'period', 'coalition', 'credit', 'build',
#        'peace', 'key', 'round', 'offer', 'federal', 'record', 'australia',
#        'september', 'war', 'league', 'revenue', 'reporter', 'authority',
#        'russia', 'november', 'announce', 'join', 'goal', 'bring',
#        'product', 'average', 'commission', 'seven', 'ago', 'agency',
#        'believe', 'deputy', 'congress', 'grow', 'american', 'season',
#        'feb', 'target', 'emu', 'source', 'likely', 'release', 'score',
#        'charge', 'free', 'israel', 'october', 'future', 'ahead', 'share',
#        'recent', 'indicator', 'republican', 'seek', 'minute', 'break',
#        'august', 'victory', 'centre', 'county', 'social', 'council', 'tue',
#        'hit', 'soccer', 'concern', 'past', 'hour', 'sell', 'clear',
#        'private', 'player', 'conservative', 'development', 'newspaper',
#        'project', 'february', 'retail', 'investor', 'west', 'palestinian',
#        'area', 'russian', 'food', 'estimate', 'bid', 'don', 'main',
#        'output', 'pressure', 'democratic', 'non', 'treasury', 'fight',
#        'annual', 'mean', 'africa', 'post', 'race', 'communist', 'fiscal',
#        'decide', 'protest', 'yeltsin', 'action', 'club', 'australian',
#        'approve', 'case', 'board', 'department', 'india', 'secretary',
#        'list', 'mar', 'line', 'question', 'jul', 'municipal', 'loan',
#        'aid', 'great', 'coupon', 'decline', 'proposal', 'form', 'provide',
#        'short', 'east', 'comment', 'despite', 'democrat', 'senior',
#        'small', 'apr', 'fail', 'region', 'cabinet', 'test', 'military',
#        'york', 'london', 'yield', 'turn', 'seat', 'socialist', 'reduce',
#        'chairman', 'israeli', 'woman', 'attack', 'white', 'survey',
#        'possible', 'income', 'stock', 'step', 'compare', 'television',
#        'jun', 'john', 'spain', 'effort', 'fell', 'net', 'launch', 'hand',
#        'north', 'consider', 'little', 'sep', 'previous', 'condition',
#        'best', 'process', 'director', 'majority', 'position', 'health',
#        'receive', 'production', 'senate', 'visit', 'approx', 'drop', 'hop',
#        'jpn', 'save', 'aim', 'moody', 'limit', 'african', 'pas', 'draw',
#        'usa', 'washington', 'delay', 'medium', 'propose', 'live', 'warn',
#        'contract', 'england', 'claim', 'view', 'champion', 'create',
#        'send', 'gmt', 'improve', 'wage', 'division', 'schedule',
#        'programme', 'voter', 'defence', 'district', 'appear', 'act',
#        'candidate', 'town', 'payment', 'gross', 'quote', 'canada', 'human',
#        'parliamentary', 'chance', 'imf', 'governor', 'hard', 'discus',
#        'cpi', 'supply', 'italian', 'army', 'kill', 'gold', 'present',
#        'western', 'important', 'operation', 'basis', 'press', 'gain',
#        'monthly', 'speak', 'feed', 'confidence', 'thing', 'away',
#        'interview', 'championship', 'urge', 'slow', 'boost', 'czech',
#        'carry', 'presidential', 'mexico', 'daily', 'debate', 'crisis',
#        'today', 'surplus', 'tie', 'accuse', 'euro', 'employment',
#        'administration', 'prepare', 'value', 'fourth', 'promise', 'desk',
#        'car', 'bad', 'negotiation', 'organisation', 'situation', 'benefit',
#        'earn', 'air', 'book', 'plant', 'buy', 'effect', 'entry', 'stop',
#        'near', 'association', 'unit', 'cause', 'manager', 'arm', 'affair',
#        'republic', 'special', 'chinese', 'statistic', 'ban', 'fear',
#        'maturity', 'brazil', 'pound', 'risk', 'stability', 'child',
#        'involve', 'loss', 'life', 'coach', 'men', 'stay', 'drive',
#        'overall', 'family', 'rebel', 'accept', 'netanyahu', 'ger', 'night',
#        'executive', 'radio', 'zealand', 'northern', 'deny', 'elect',
#        'push', 'weekend', 'paper', 'privatisation', 'independent',
#        'information', 'defeat', 'outside', 'program', 'man', 'require',
#        'qualify', 'poor', 'suggest', 'street', 'korea', 'able', 'treaty',
#        'research', 'shoot', 'title', 'paris', 'partner', 'crown',
#        'forward', 'representative', 'soon', 'corp', 'energy', 'role',
#        'david', 'award', 'japanese', 'link', 'young', 'event', 'range',
#        'assembly', 'moscow', 'finish', 'pakistan', 'land', 'trend',
#        'employee', 'dispute', 'summit', 'politician', 'reject',
#        'percentage', 'hope', 'focus', 'complete', 'democracy', 'activity',
#        'producer', 'institute', 'fast', 'ireland', 'pension', 'regional',
#        'community', 'franc', 'sept', 'manufacture', 'reason', 'opinion',
#        'legal', 'write', 'michael', 'tour', 'serve', 'staff', 'winner',
#        'yen', 'challenge', 'develop', 'construction', 'violence',
#        'beijing', 'currently', 'anti', 'progress', 'dole', 'attempt',
#        'cover', 'sport', 'rally', 'body', 'civil', 'kohl', 'taiwan',
#        'pact', 'speech', 'relation', 'nearly', 'settlement', 'publish',
#        'education', 'criterion', 'standard', 'ensure', 'troop', 'course',
#        'peter', 'alliance', 'threaten', 'lot', 'tough', 'stage',
#        'obligation', 'indian', 'confirm', 'inning', 'sweden', 'management',
#        'oppose', 'rival', 'impact', 'affect', 'replace', 'appeal',
#        'legislation', 'maintain', 'sure', 'bundesbank', 'produce',
#        'probably', 'asset', 'deposit', 'wag', 'wing', 'aaa', 'premier',
#        'san', 'road', 'feel', 'movement', 'draft', 'hear', 'water',
#        'study', 'america', 'cash', 'commercial', 'represent', 'double',
#        'supporter', 'trillion', 'ease', 'pledge', 'ppi', 'available',
#        'suffer', 'competitive', 'difficult', 'train', 'happen', 'saw',
#        'improvement', 'review', 'refuse', 'station', 'university',
#        'subject', 'worth', 'thousand', 'iraq', 'hospital', 'recently',
#        'miss', 'fact', 'insurance', 'bureau', 'feature', 'manage',
#        'package', 'favour', 'arab', 'moslem', 'island', 'turkey',
#        'competition', 'bear', 'session', 'fra', 'province', 'profit',
#        'arrest', 'recovery', 'really', 'introduce', 'prod', 'personal',
#        'lend', 'fix', 'positive', 'property', 'block', 'metre',
#        'singapore', 'direct', 'corruption', 'pick', 'address', 'labor',
#        'pro', 'die', 'port', 'performance', 'heart', 'cooperation',
#        'delivery', 'liberal', 'adjust', 'vice', 'cricket', 'eastern',
#        'achieve', 'english', 'factor', 'adj', 'express', 'middle',
#        'declare', 'weak', 'injury', 'prevent', 'pre', 'wait', 'enter',
#        'diplomat', 'canadian', 'approval', 'rest', 'southern', 'extend',
#        'cross', 'revise', 'arafat', 'battle', 'exist', 'mission',
#        'morning', 'matter', 'let', 'negotiate', 'red', 'field', 'black',
#        'poland', 'issuer', 'welfare', 'transport', 'impose', 'chancellor',
#        'tournament', 'asian', 'ball', 'worry', 'death', 'star', 'border',
#        'texas', 'irish', 'swiss', 'ready', 'damage', 'joint', 'struggle',
#        'thailand', 'rank', 'ally', 'tonne', 'bonn', 'federation', 'threat',
#        'drug', 'resign', 'chicago', 'tennis', 'age', 'lira', 'century',
#        'chirac', 'letter', 'smith', 'immediately', 'sanction', 'asia',
#        'maastricht', 'morgan', 'transfer', 'mid', 'avoid', 'par',
#        'surprise', 'justice', 'fuel', 'necessary', 'king', 'argue',
#        'waigel', 'doubt', 'contribute', 'wto', 'independence', 'judge',
#        'predict', 'serb', 'reflect', 'track', 'fifth', 'striker', 'cent',
#        'appoint', 'blair', 'spanish', 'apply', 'territory', 'indonesia',
#        'grant', 'welcome', 'wholesale', 'reduction', 'dutch', 'space',
#        'expectation', 'borrow', 'park', 'paul', 'institution', 'defend',
#        'operate', 'advance', 'argentina', 'captain', 'purchase', 'arrive',
#        'huge', 'constitution', 'guarantee', 'gap', 'individual',
#        'potential', 'lack', 'robert', 'attend', 'difference',
#        'opportunity', 'film', 'different', 'philippine', 'expert', 'grind',
#        'student', 'soviet', 'trust', 'refugee', 'austria', 'similar',
#        'history', 'success', 'telephone', 'scheme', 'referendum',
#        'announcement', 'certain', 'employer', 'trial', 'george',
#        'implement', 'commitment', 'global', 'romania', 'facility',
#        'sydney', 'dealer', 'agriculture', 'career', 'commerce', 'request',
#        'preliminary', 'emerge', 'ship', 'population', 'instead',
#        'indicate', 'tighten', 'penalty', 'trouble', 'amendment', 'seed',
#        'motor', 'wicket', 'pace', 'california', 'airline', 'determine',
#        'sen', 'bulgaria', 'especially', 'wide', 'strength', 'lift',
#        'investigation', 'establish', 'fly', 'decade', 'auction', 'prov',
#        'panel', 'minimum', 'son'],
#       dtype='<U140')

# %%
count_vectorizer_with_stem.stop_words_
# Out:
# {'confederaiton',
#  'larco',
#  'commnunity',
#  'vastrup',
#  'buiterprofessor',
#  'mitteleuropa',
#  'destablised',
#  'crownstournament',
#  'ardmorelast',
#  'bereturned',
#  'windesmond',
#  'meddlesome',
#  'zippo',
#  'malcolmson',
#  'haywards',
#  'sorayuth',
#  'andequipping',
#  'despuite',
#  'optimitic',
#  'hinchev',
#  'giove',
#  'brookvale',
#  'acceptbids',
#  'pedagogy',
#  'despitehaving',
#  'yapusham',
#  'pelowski',
#  'underhandedness',
#  'hvidsteen',
#  'scheduledsunday',
#  'masachusettsre',
#  'brainware',
#  'dgiv',
#  'lesuirely',
#  'montmelo',
#  'maturityat',
#  'telpek',
#  'jea',
#  'musyoki',
#  'antigovernment',
#  'lithuanialatvia',
#  'turlough',
#  'tesobono',
#  'abortedtransmission',
#  'kliore',
#  'trompe',
#  'chilblain',
#  'mohammedodds',
#  'dybkj',
#  'lelouis',
#  'radosevic',
#  'standardisedinternational',
#  'saiddoohan',
#  'tighther',
#  'forecastcommissioned',
#  'nympheas',
#  'pramilla',
#  'ady',
#  'quaterly',
#  'thanr',
#  'lacq',
#  'khemani',
#  'wagi',
#  'rabbitohs',
#  'volvos',
#  'caminata',
#  'statistik',
#  'courtay',
#  'ccourse',
#  'nedzad',
#  'endedin',
#  'leftqueensland',
#  'upwelling',
#  'soccerplayoff',
#  'trihadmodjo',
#  'finkler',
#  'shuklenk',
#  'kouomegni',
#  'maximim',
#  'chloroquine',
#  'velcro',
#  'prowness',
#  'saunterer',
#  'trishel',
#  'shok',
#  'pospones',
#  'officail',
#  'anatnag',
#  'jakeman',
#  'criticsopponents',
#  'bangaldesh',
#  'headachestechnicians',
#  'anais',
#  'etu',
#  'vleeds',
#  'ftk',
#  'kenaan',
#  'moundstate',
#  'gusev',
#  'uarter',
#  'lazovic',
#  'capauano',
#  'nesky',
#  'yyphilip',
#  'vitcheva',
#  'cartoucherie',
#  'tradeability',
#  'laurinburg',
#  'poposed',
#  'techapaiboon',
#  'chehlum',
#  'bondaruk',
#  'marrabentas',
#  'pleuvast',
#  'leron',
#  'gehan',
#  'vvenezuela',
#  'dovrat',
#  'strictlty',
#  'celestinebabayaro',
#  'enniscorthy',
#  'bertos',
#  'socioambiental',
#  'berglund',
#  'brosred',
#  'vacheara',
#  'chauvelier',
#  'defamationthe',
#  'compenstated',
#  'preferrence',
#  'platone',
#  'pasoutheast',
#  'piercy',
#  'desjarddins',
#  'roi',
#  'sephali',
#  'causative',
#  'aizpurua',
#  'androgen',
#  'paparisov',
#  'wctc',
#  'havingwon',
#  'shravan',
#  'aldredo',
#  'geliebte',
#  'bulega',
#  'elizabethbut',
#  'ssendon',
#  'ise',
#  'azuyev',
#  'socis',
#  'enterovirus',
#  'changetorreon',
#  'provisionalbb',
#  'kifiza',
#  'pointseach',
#  'equilibre',
#  'nicholsons',
#  'andthird',
#  'tuesdayeconomists',
#  'hassanzadeh',
#  'staller',
#  'reidbest',
#  'importedraw',
#  'quinnsworth',
#  'atvalderrama',
#  'litynski',
#  'wouldwin',
#  'sarju',
#  'cebrian',
#  'blairpolls',
#  'cucuzza',
#  'behaviourist',
#  'thorogood',
#  'mcmurtry',
#  'gmtkarlsruhe',
#  'sanciu',
#  'nhongvongsithi',
#  'hec',
#  'montogomerieshare',
#  'edouwe',
#  'borshchev',
#  'portgage',
#  'anindependent',
#  'mrket',
#  'coredeutsche',
#  'iraqhollis',
#  'harlon',
#  'releasedetails',
#  'reias',
#  'ozenc',
#  'parenthetically',
#  'acheiving',
#  'fomenko',
#  'manakov',
#  'bengland',
#  'surapon',
#  'dorathy',
#  'nimalsiri',
#  'caranica',
#  'unshipped',
#  'gormless',
#  'derial',
#  'foppish',
#  'cournond',
#  'sequal',
#  'optionsthe',
#  'thelimelight',
#  'atz',
#  'francsico',
#  'undersirable',
#  'ultless',
#  'holdkenneth',
#  'slightit',
#  'dependance',
#  'dxcise',
#  'tablecloth',
#  'katikati',
#  'farmache',
#  'thejune',
#  'ribuffo',
#  'zorileanu',
#  'consommateur',
#  'offchina',
#  'miyahara',
#  'bresson',
#  'synaptic',
#  'chinhae',
#  'burkinabes',
#  'veryhigh',
#  'declaredrichmond',
#  'confirmned',
#  'yasui',
#  'rapprochment',
#  'tocantin',
#  'yaktuia',
#  'guertin',
#  'overstriangular',
#  'usdoj',
#  'boram',
#  'haigermoser',
#  'andalonzo',
#  'andto',
#  'thisthursday',
#  'trigg',
#  'maurilio',
#  'gioiosa',
#  'ocab',
#  'aland',
#  'cyprusthis',
#  'andphiladelphia',
#  'platten',
#  'winnersingspiel',
#  'themselvesethical',
#  'nieuwburg',
#  'rekeshius',
#  'playwriting',
#  'cenusus',
#  'budgetstatement',
#  'besubject',
#  'deserivig',
#  'fincher',
#  'satelitte',
#  'tassier',
#  'unprisings',
#  'fuamatu',
#  'calument',
#  'impressionistically',
#  'andreapoon',
#  'demanddeposits',
#  'avdiyenko',
#  'pricerise',
#  'lamasoure',
#  'dunseth',
#  'braunder',
#  'faks',
#  'leadingsecond',
#  'singaporisation',
#  'cassese',
#  'hilditch',
#  'systemof',
#  'ntic',
#  'disloge',
#  'yocum',
#  'hesen',
#  'rybachuk',
#  'domoina',
#  'bayernliga',
#  'usand',
#  'mukhi',
#  'vukota',
#  'adylshaiyk',
#  'guiney',
#  'relatship',
#  'figt',
#  'gorachev',
#  'tauplitz',
#  'hegazi',
#  'druy',
#  'atmos',
#  'oversmalaysia',
#  'nsm',
#  'cellcom',
#  'gepi',
#  'koulamallaheducation',
#  'eminate',
#  'tainan',
#  'vivacqua',
#  'exeptionally',
#  'wardle',
#  'saidnets',
#  'remsberger',
#  'purcahse',
#  'announcemnent',
#  'shangling',
#  'tranmission',
#  'roundleander',
#  'malescenko',
#  'kaharan',
#  'deliverieswith',
#  'kraal',
#  'authorityverbal',
#  'thetry',
#  'fullsquad',
#  'legislatives',
#  'aptma',
#  'amotz',
#  'communalisation',
#  'kuntarahoitus',
#  'piney',
#  'betweenfinanzamt',
#  'mujkic',
#  'vrs',
#  'progrmame',
#  'tshsisekedi',
#  'jetchev',
#  'advertizement',
#  'wmo',
#  'sipri',
#  'twohamilton',
#  'moskova',
#  'puehrinher',
#  'apray',
#  'schobersberger',
#  'correcct',
#  'cyclinder',
#  'plowright',
#  'vada',
#  'scottdavis',
#  'warut',
#  'bouterese',
#  'mortician',
#  'lindsley',
#  'shandwick',
#  'jumayal',
#  'chazalet',
#  'flemensirth',
#  'inforced',
#  'sawczuk',
#  'exmployment',
#  'toacknowledge',
#  'hilleary',
#  'refud',
#  'uanimously',
#  'ududgov',
#  'distino',
#  'caseros',
#  'nozoe',
#  'sru',
#  'mroudjae',
#  'sambat',
#  'filmstars',
#  'brevik',
#  'neua',
#  'hajja',
#  'kmgh',
#  'instuitutions',
#  'jieyang',
#  'asegedetch',
#  'douarnenez',
#  'duerounding',
#  'jounral',
#  'hurredly',
#  'njukic',
#  'kiptarus',
#  'prestes',
#  'roledeveloping',
#  'fevetraph',
#  'saybut',
#  'marassi',
#  'obeservers',
#  'dyslexics',
#  'solih',
#  'rimmer',
#  'longviewstate',
#  'suncoast',
#  'shameti',
#  'rushin',
#  'abnout',
#  'ihsanullah',
#  'semiannuall',
#  'unprovided',
#  'figge',
#  'celebraytion',
#  'moenchengladbachfirst',
#  'yuqing',
#  'byemixed',
#  'hotze',
#  'pase',
#  'rauiri',
#  'segmentstoolsconsumer',
#  'dorught',
#  'gabrieli',
#  'alkena',
#  'skripallein',
#  'paix',
#  'ispermitted',
#  'doublesthird',
#  'neededthe',
#  'sailmaking',
#  'dovlat',
#  'qualifierjavier',
#  'stretegist',
#  'nancun',
#  'nucleic',
#  'mityikov',
#  'loveiii',
#  'eyecare',
#  'beingheld',
#  'tremedous',
#  'slimdown',
#  'moresbyanother',
#  'classicexhibition',
#  'flagcarrier',
#  'pecten',
#  'quintile',
#  'elmet',
#  'fjeld',
#  'hingoli',
#  'birtwhistle',
#  'mellot',
#  'faecal',
#  'lscorer',
#  'battlegroundthe',
#  'kentung',
#  'dabrowska',
#  'abdoulhamid',
#  'taekwon',
#  'rennert',
#  'blerk',
#  'eccott',
#  'knowlegeable',
#  'brigo',
#  'canberrathe',
#  'publier',
#  'bernini',
#  'arinella',
#  'metiulous',
#  'paymentthereof',
#  'nuzzle',
#  'savea',
#  'easenegotiations',
#  'aquaplane',
#  'sre',
#  'tredyfein',
#  'fortysomethings',
#  'plywaczewski',
#  'kokovinets',
#  'weloming',
#  'wealthly',
#  'froim',
#  'reinjected',
#  'grimit',
#  'whihc',
#  'inccompetitive',
#  'agendathe',
#  'bakhtiiar',
#  'mawenh',
#  'cheical',
#  'relationsprotocol',
#  'borrowiwng',
#  'forsgardh',
#  'arnaudclement',
#  'goolburthunoo',
#  'pixley',
#  'berzosa',
#  'dlabisi',
#  'prayitno',
#  'opratives',
#  'jaszczyk',
#  'setien',
#  'fujimorivice',
#  'torinomay',
#  'lovasz',
#  'effectuee',
#  'brenes',
#  'mikeal',
#  'bridgitte',
#  'yugoslalvia',
#  'sanmarinogroup',
#  'elucidate',
#  'risques',
#  'bigbee',
#  'yeshans',
#  'capdeviellesouth',
#  'swissman',
#  'lisouba',
#  'ahuja',
#  'spreadingdespite',
#  'sinyavsky',
#  'bugdte',
#  'lehmans',
#  'interregnum',
#  'prodice',
#  'radicial',
#  'pramoedya',
#  'wakeham',
#  'matu',
#  'elabeh',
#  'antonybowie',
#  'tasy',
#  'babale',
#  'meditatively',
#  'onlyoccasionally',
#  'verbeke',
#  'monopolistically',
#  'ecy',
#  'seashell',
#  'cvi',
#  'mobiliarios',
#  'cuchulain',
#  'doikov',
#  'vfr',
#  'offeature',
#  'elx',
#  'portifolios',
#  'dunjerski',
#  'partnersartemis',
#  'misapprehension',
#  'vaudrey',
#  'dominace',
#  'ekeberg',
#  'roundshuzo',
#  'vangaindrano',
#  'folli',
#  'revenger',
#  'daneshvari',
#  'cooreman',
#  'malcolmbowling',
#  'unhitch',
#  'cupplace',
#  'conchitamartinez',
#  'oacier',
#  'aloys',
#  'bresults',
#  'prevoie',
#  'cabarceneo',
#  'jaroslavsakala',
#  'watties',
#  'feeauxerre',
#  'sprined',
#  'therewere',
#  'yoshiharu',
#  'amnouayphone',
#  'caucoto',
#  'esatern',
#  'hurtin',
#  'faciltiy',
#  'karnatakaattack',
#  'bahija',
#  'developersthe',
#  'utojo',
#  'sark',
#  'copos',
#  'regrat',
#  'carrollheptathlon',
#  'sahelawassa',
#  'sinek',
#  'safonova',
#  'februa',
#  'atlan',
#  'unconfirmedreports',
#  'kolonaki',
#  'amitie',
#  'soni',
#  'pavan',
#  'ceilinged',
#  'isreceived',
#  'alnhoa',
#  'neededlike',
#  'yesnetherlands',
#  'novemberfor',
#  'pasar',
#  'samudi',
#  'montrealny',
#  'asies',
#  'substitutesfollowing',
#  'indicatively',
#  'enescu',
#  'smorgasboard',
#  'mattingly',
#  'abogu',
#  'recalcitrants',
#  'himplay',
#  'fnk',
#  'valki',
#  'mayority',
#  'mththe',
#  'silovs',
#  'thislte',
#  'inflexiblility',
#  'januaryagainst',
#  'threequarter',
#  'ministryon',
#  'bhc',
#  'hdated',
#  'atheneum',
#  'geotail',
#  'brentgeiberger',
#  'telegraphracing',
#  'taejoneuropean',
#  'portilla',
#  'outgaining',
#  'courtesan',
#  'leguina',
#  'missiri',
#  'pricingfinancing',
#  'disctinct',
#  'wolfeand',
#  'umbra',
#  'gresson',
#  'problemactivists',
#  'grigio',
#  'mezzani',
#  'werenoted',
#  'cordera',
#  'correspondentross',
#  'safinia',
#  'veysel',
#  'colonystate',
#  'propellor',
#  'meansthat',
#  'homerand',
#  'dogstar',
#  'suntel',
#  'suada',
#  'piw',
#  'obeegadooland',
#  'moskal',
#  'kotka',
#  'vozhd',
#  'inyama',
#  'vzglyad',
#  'vkongsvinger',
#  'baoviet',
#  'uncrossable',
#  'authoritynew',
#  'clyonnais',
#  'secoring',
#  'thoughtthis',
#  'encompasing',
#  'trst',
#  'icmi',
#  'kilimanyako',
#  'unrefunded',
#  'mercusor',
#  'tarlue',
#  'kostantinos',
#  'theactive',
#  'legros',
#  'millionexpenditure',
#  'murderedfernandez',
#  'buliding',
#  'linehaul',
#  'hpuerto',
#  'preosecution',
#  'ruffley',
#  'previuosly',
#  'leaguechelsea',
#  'hardworker',
#  'peliminary',
#  'lighthizer',
#  'monthh',
#  'yastrzhembski',
#  'neastr',
#  'escuduospayment',
#  'frithjof',
#  'particarly',
#  'yamachi',
#  'coverdale',
#  'commandere',
#  'womenni',
#  'delocalise',
#  'hilla',
#  'systmes',
#  'sheadded',
#  'powerplant',
#  'houstonphiladelphia',
#  'shteinbuka',
#  'talaben',
#  'courten',
#  'kapitanis',
#  'oaed',
#  'wahaha',
#  'adoptedafter',
#  'outpunching',
#  'pakhoed',
#  'omdal',
#  'redoubtable',
#  'reaonable',
#  'phyto',
#  'mychael',
#  'sudetenland',
#  'retiredjiri',
#  'distriubte',
#  'frameworkenabling',
#  'hisbullahshipping',
#  'yakutish',
#  'geler',
#  'epscor',
#  'libbed',
#  'wynford',
#  'tieliverpool',
#  'thuemler',
#  'afanassievsky',
#  'arrowed',
#  'someways',
#  'consequencies',
#  'exluded',
#  'misuar',
#  'palmyrare',
#  'runthird',
#  'sixthstage',
#  'visionwe',
#  'despie',
#  'ulukayev',
#  'unker',
#  'tellawi',
#  'trusteee',
#  'chapulsat',
#  'kallevainola',
#  'easiermotorcycles',
#  'corgi',
#  'nabokov',
#  'barryforeign',
#  'brainchilld',
#  'gordonbrand',
#  'edinastate',
#  'salaf',
#  'mohammmed',
#  'vage',
#  'pertinentinformation',
#  'hmself',
#  'ihring',
#  'thorpedo',
#  'atfive',
#  'garisson',
#  'depoliticises',
#  'pasostate',
#  'pilipino',
#  'castelazo',
#  'generalwednesday',
#  'areawould',
#  'poliomyelitis',
#  'fourleague',
#  'newcastlestandings',
#  'vengsarkar',
#  'aurica',
#  'sorellina',
#  'superloos',
#  'konstantinbratoshov',
#  'xxxii',
#  'addedkinnock',
#  'woolfall',
#  'haarvard',
#  'rhandhawa',
#  'swedenteam',
#  'wrti',
#  'pctemployed',
#  'tprb',
#  'berecommended',
#  'gleneagles',
#  'emuto',
#  'leasamaivao',
#  'synthelabo',
#  'bugallo',
#  'namenska',
#  'ferlaino',
#  'dastardliness',
#  'jeida',
#  'priemyselna',
#  'vittrup',
#  'couragouesfilly',
#  'isreducing',
#  'chennault',
#  'celina',
#  'impovrishment',
#  'joulani',
#  'klingender',
#  'internationalbrands',
#  'minutage',
#  'matskevichstandardisation',
#  'basutholand',
#  'areespecially',
#  'theorem',
#  'nykanen',
#  'chikafumi',
#  'rabasa',
#  'nationalites',
#  'pictureseque',
#  'haqnext',
#  'brotherstalin',
#  'chimmoku',
#  'jonatanjohansson',
#  'gorbandmitry',
#  'celestis',
#  'informestado',
#  'rtbaioverldfiun',
#  'attemptto',
#  'compard',
#  'arcata',
#  'syariah',
#  'disuption',
#  'ukans',
#  'moritzburg',
#  'fundacja',
#  'septembertotal',
#  'adjopt',
#  'bryanyoung',
#  'singlescarlos',
#  'sabear',
#  'pravachol',
#  'sorrayuth',
#  'urbs',
#  'mihir',
#  'allowi',
#  'addisonl',
#  'mejillones',
#  'kabaija',
#  'whohelped',
#  'bodrogi',
#  'milosivic',
#  'productionsltd',
#  'luxembourgeois',
#  'aftereffect',
#  'rendsburg',
#  'inebetude',
#  'damningly',
#  'maipu',
#  'discolouration',
#  'ulladulla',
#  'conmgress',
#  'mouelle',
#  'lichti',
#  'ganlu',
#  'wantto',
#  'pipat',
#  'huapu',
#  'ezeikel',
#  'horster',
#  'saetra',
#  'prospersmall',
#  'tourismreceipts',
#  'bendeck',
#  'issance',
#  'wagonlit',
#  'moencheng',
#  'imborgia',
#  'patra',
#  'foreccasts',
#  'blnbank',
#  'swedenfirst',
#  'garing',
#  'sakhon',
#  'pasifik',
#  'olfaction',
#  'stuctural',
#  'possibliity',
#  'perdana',
#  'ampaza',
#  'politicas',
#  'henger',
#  'authoritiarian',
#  'suday',
#  'ndepo',
#  'donmez',
#  'palestiniansthe',
#  'braouzec',
#  'quaintly',
#  'baffa',
#  'felderer',
#  'prizma',
#  'mohyeddin',
#  'hockeyroo',
#  'anopinion',
#  'exilee',
#  'petrucciani',
#  'sagai',
#  'paulyn',
#  'widuri',
#  'citta',
#  'sunnyside',
#  'sidorczuk',
#  'sterlingcity',
#  'dollase',
#  'benellwood',
#  'andamerican',
#  'kokotou',
#  'stearinviva',
#  'fergon',
#  'swari',
#  'walkoverhana',
#  'hiri',
#  'cheb',
#  'rozalina',
#  'euyope',
#  'peebler',
#  'fratia',
#  'oelmuehle',
#  'antiono',
#  'governnor',
#  'asfari',
#  'sakaigawa',
#  'cherng',
#  'remainingseven',
#  'dixmoor',
#  'withington',
#  'stichaces',
#  'thara',
#  'maturies',
#  'wirt',
#  'nry',
#  'dsitrict',
#  'sailard',
#  'galibali',
#  'mollema',
#  'bmci',
#  'baban',
#  'herler',
#  'kadje',
#  'shergottite',
#  'thecriterium',
#  'jonolav',
#  'zagliveri',
#  'carbombs',
#  'assat',
#  'recogition',
#  'kanasaki',
#  'ajupov',
#  'aviolat',
#  'organismos',
#  'khonsavanh',
#  'yardrun',
#  'khodotovich',
#  'kipiani',
#  'wipsawed',
#  'bmuralitharan',
#  'anydifferent',
#  'fillmorel',
#  'obuvshchik',
#  'reprsent',
#  'pilati',
#  'shedder',
#  'unexportable',
#  'basleine',
#  'finalsjennifer',
#  'publica',
#  'withplayers',
#  'kutsiy',
#  'trancheeuro',
#  'damienflemming',
#  'tolian',
#  'bullfrog',
#  'nothiung',
#  'projectmandatory',
#  'johngielguld',
#  'leebron',
#  'ifrane',
#  'baselyear',
#  'tohead',
#  'brakets',
#  'elihu',
#  'inlocal',
#  'seloc',
#  'springvillel',
#  'lelingoana',
#  'alsf',
#  'kripak',
#  'yoshino',
#  'firther',
#  'stinginess',
#  'nzimeni',
#  'sudarjono',
#  'quentrec',
#  'finalsresults',
#  'dispositon',
#  'cirebon',
#  'fonavi',
#  'prerov',
#  'schull',
#  ...}

# %%
scipy.io.mmwrite('countvect-articles', doc_term)

# %%
doc_term
# Out:
# <202399x84168 sparse matrix of type '<class 'numpy.int64'>'
# 	with 19996058 stored elements in Compressed Sparse Row format>

# %%
(NUM_ARTICLES,NUM_WORDS)
# Out:
# (202399, 84168)

# %%
count_vectorizer_with_stem.get_feature_names()
# Out:
# ['________________________________________________________________',
#  'aaa',
#  'aaaa',
#  'aaaaa',
#  'aaaambac',
#  'aaabaa',
#  'aaaconnie',
#  'aaadated',
#  'aaadelivery',
#  'aaadtd',
#  'aaadue',
#  'aaafgic',
#  'aaafnma',
#  'aaafsa',
#  'aaainsurance',
#  'aaalong',
#  'aaamaturity',
#  'aaambia',
#  'aaano',
#  'aaanotes',
#  'aaapermanent',
#  'aaasale',
#  'aaaund',
#  'aaaunder',
#  'aaaunderlying',
#  'aabpara',
#  'aaccess',
#  'aachen',
#  'aaconfirmed',
#  'aad',
#  'aadated',
#  'aadelivery',
#  'aadue',
#  'aaeu',
#  'aafgic',
#  'aafitch',
#  'aafli',
#  'aafsa',
#  'aage',
#  'aah',
#  'aai',
#  'aajkal',
#  'aal',
#  'aalame',
#  'aalborg',
#  'aalcohol',
#  'aalst',
#  'aalto',
#  'aaltonen',
#  'aam',
#  'aama',
#  'aamaturity',
#  'aambac',
#  'aambia',
#  'aamerican',
#  'aami',
#  'aamir',
#  'aamodt',
#  'aamp',
#  'aamulehti',
#  'aan',
#  'aand',
#  'aandewiel',
#  'aanz',
#  'aapo',
#  'aapr',
#  'aaqib',
#  'aarau',
#  'aardvark',
#  'aare',
#  'aarebrot',
#  'aarej',
#  'aarhus',
#  'aaron',
#  'aarp',
#  'aart',
#  'aartsen',
#  'aasale',
#  'aase',
#  'aashish',
#  'aat',
#  'aattentionthe',
#  'aau',
#  'aaunderlying',
#  'aaustralia',
#  'aaustria',
#  'aauxerre',
#  'aaverage',
#  'aavg',
#  'aaviksoo',
#  'aawi',
#  'aba',
#  'ababa',
#  'abac',
#  'abacha',
#  'aback',
#  'abaco',
#  'abacus',
#  'abad',
#  'abadala',
#  'abadia',
#  'abadou',
#  'abag',
#  'abalances',
#  'abandon',
#  'abandonded',
#  'abandonment',
#  'abandonned',
#  'abang',
#  'abank',
#  'abare',
#  'abascal',
#  'abassi',
#  'abate',
#  'abatement',
#  'abattoir',
#  'abaza',
#  'abazaj',
#  'abazi',
#  'abb',
#  'abba',
#  'abbadi',
#  'abbagnale',
#  'abbas',
#  'abbasbeyli',
#  'abbasi',
#  'abbasov',
#  'abbass',
#  'abbaye',
#  'abbe',
#  'abberation',
#  'abbey',
#  'abbie',
#  'abbio',
#  'abbot',
#  'abbott',
#  'abbotto',
#  'abbotts',
#  'abboud',
#  'abbreviate',
#  'abbreviation',
#  'abbud',
#  'abc',
#  'abcl',
#  'abd',
#  'abdal',
#  'abdala',
#  'abdalla',
#  'abdallah',
#  'abdallahi',
#  'abdel',
#  'abdelardo',
#  'abdelatif',
#  'abdelaziz',
#  'abdelbaki',
#  'abdelfahid',
#  'abdelhadi',
#  'abdelhafid',
#  'abdelhajid',
#  'abdelhak',
#  'abdelhamid',
#  'abdelkader',
#  'abdelkebir',
#  'abdelkerim',
#  'abdelkrim',
#  'abdella',
#  'abdellah',
#  'abdellaoui',
#  'abdellatif',
#  'abdelmajid',
#  'abdelrahim',
#  'abdelrazeq',
#  'abdelslam',
#  'abdelwahab',
#  'abdennour',
#  'abderamane',
#  'abdere',
#  'abderrahim',
#  'abderrahman',
#  'abderrahmane',
#  'abdeslam',
#  'abdessadeq',
#  'abdessalam',
#  'abdi',
#  'abdic',
#  'abdicate',
#  'abdication',
#  'abdin',
#  'abdollah',
#  'abdomen',
#  'abdominal',
#  'abdon',
#  'abdool',
#  'abdorrahman',
#  'abdou',
#  'abdoujaparov',
#  'abdoulaye',
#  'abdoulmoumine',
#  'abdouramane',
#  'abduct',
#  'abduction',
#  'abductor',
#  'abdujaparov',
#  'abdul',
#  'abdulah',
#  'abdulatipov',
#  'abdulaziz',
#  'abdulillah',
#  'abduljabbar',
#  'abdulkadir',
#  'abdulkareem',
#  'abdulkarim',
#  'abdulkerim',
#  'abdulla',
#  'abdullah',
#  'abdullahi',
#  'abdullai',
#  'abdullatif',
#  'abdullayev',
#  'abdullo',
#  'abdulmejid',
#  'abdulrahman',
#  'abdulrazzaq',
#  'abdulsalam',
#  'abdulwahab',
#  'abdumalik',
#  'abdur',
#  'abdurahman',
#  'abdurahmon',
#  'abdurrab',
#  'abdurrahman',
#  'abdus',
#  'abdusattor',
#  'abduvaliyev',
#  'abduvokhid',
#  'abduzhaparov',
#  'abdyl',
#  'abe',
#  'abed',
#  'abedi',
#  'abedian',
#  'abedin',
#  'abednego',
#  'abedzadeh',
#  'abeer',
#  'abegg',
#  'abeijon',
#  'abel',
#  'abelardo',
#  'abelekan',
#  'abellanal',
#  'abendblatt',
#  'abendzeitung',
#  'abeokuta',
#  'abercrombie',
#  'aberdeen',
#  'aberrant',
#  'aberration',
#  'aberson',
#  'aberystwyth',
#  'abessole',
#  'abet',
#  'abete',
#  'abey',
#  'abeyance',
#  'abf',
#  'abhijit',
#  'abhisit',
#  'abhor',
#  'abhorrence',
#  'abhorrent',
#  'abi',
#  'abid',
#  'abida',
#  'abidance',
#  'abiddin',
#  'abide',
#  'abidin',
#  'abidine',
#  'abidjan',
#  'abie',
#  'abigail',
#  'abilene',
#  'abilio',
#  'ability',
#  'abimael',
#  'abingdon',
#  'abington',
#  'abiodun',
#  'abiola',
#  'abioudun',
#  'abiove',
#  'abitbol',
#  'abitration',
#  'abitrigo',
#  'abiyev',
#  'abject',
#  'abkhaz',
#  'abkhazia',
#  'abkhazian',
#  'abl',
#  'ablade',
#  'ablasse',
#  'ablaze',
#  'able',
#  'ablett',
#  'ably',
#  'abm',
#  'abma',
#  'abn',
#  'abnamro',
#  'abnd',
#  'abnegation',
#  'abner',
#  'abnormal',
#  'abnormality',
#  'abnormally',
#  'abnormals',
#  'aboagye',
#  'aboard',
#  'abode',
#  'abolhassan',
#  'abolish',
#  'abolishment',
#  'abolition',
#  'abolute',
#  'abominable',
#  'abomination',
#  'abonneville',
#  'abook',
#  'aborad',
#  'aborginal',
#  'aborgines',
#  'aboriginal',
#  'aborigine',
#  'aborishade',
#  'abort',
#  'abortion',
#  'abortionist',
#  'abortive',
#  'abou',
#  'aboubacar',
#  'aboubacaryouth',
#  'aboudjerra',
#  'abound',
#  'abour',
#  'aboveground',
#  'abp',
#  'abpi',
#  'abr',
#  'abra',
#  'abraha',
#  'abraham',
#  'abraitis',
#  'abram',
#  'abramov',
#  'abramova',
#  'abramovich',
#  'abrams',
#  'abramson',
#  'abrao',
#  'abrar',
#  'abrasion',
#  'abrasive',
#  'abreast',
#  'abrego',
#  'abreu',
#  'abri',
#  'abridge',
#  'abrie',
#  'abril',
#  'abroad',
#  'abroard',
#  'abrogate',
#  'abrogation',
#  'abrupt',
#  'abruptly',
#  'abruptness',
#  'abruzzi',
#  'absa',
#  'abscence',
#  'abscess',
#  'abscond',
#  'absdf',
#  'absence',
#  'absense',
#  'absent',
#  'absentee',
#  'absenteeism',
#  'absentia',
#  'absentions',
#  'absolute',
#  'absolutely',
#  'absolution',
#  'absolve',
#  'absorb',
#  'absorbent',
#  'absorber',
#  'absorbtion',
#  'absorption',
#  'absoutely',
#  'abstain',
#  'abstainer',
#  'abstemious',
#  'abstensions',
#  'abstention',
#  'abstentionist',
#  'abstinence',
#  'abstract',
#  'abstraction',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'abt',
#  'abu',
#  'abubacar',
#  'abubakar',
#  'abudget',
#  'abudu',
#  'abufazel',
#  'abuilding',
#  'abuja',
#  'abuksis',
#  'abul',
#  'abulgazin',
#  'abundance',
#  'abundant',
#  'abundantly',
#  'abundis',
#  'aburas',
#  'aburizal',
#  'aburto',
#  'abuse',
#  'abuser',
#  'abusive',
#  'abut',
#  'abutu',
#  'abuzz',
#  'abv',
#  'abvv',
#  'aby',
#  'abysmal',
#  'abysmally',
#  'abzac',
#  'aca',
#  'acabq',
#  'acacia',
#  'academia',
#  'academic',
#  'academica',
#  'academically',
#  'academician',
#  'academicos',
#  'academie',
#  'academy',
#  'acadia',
#  'acapacity',
#  'acapulco',
#  'acar',
#  'acas',
#  'acb',
#  'acc',
#  'accabn',
#  'accc',
#  'acccept',
#  'acccepted',
#  'acccord',
#  'acccording',
#  'acccount',
#  'acccounts',
#  'acccused',
#  'accd',
#  'accede',
#  'acceed',
#  'accelaration',
#  'accelerate',
#  'acceleration',
#  'accelerator',
#  'accent',
#  'accentuate',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptableproposal',
#  'acceptably',
#  'acceptance',
#  'acces',
#  'access',
#  'accessibility',
#  'accessible',
#  'accession',
#  'accessory',
#  'accessportnet',
#  'accgunt',
#  'acci',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidently',
#  'accise',
#  'accival',
#  'accj',
#  'acclaim',
#  'acclamation',
#  'acclerated',
#  'acclerating',
#  'accleration',
#  'acclimate',
#  'acclimatisation',
#  'acclimatise',
#  'acclimatize',
#  'accnt',
#  'accoceberry',
#  'accola',
#  'accolade',
#  'accommodate',
#  'accommodation',
#  'accommodative',
#  'accomodate',
#  'accomodated',
#  'accomodating',
#  'accomodation',
#  'accomodative',
#  'accompaniment',
#  'accompany',
#  'accompli',
#  'accomplice',
#  'accomplish',
#  'accomplishment',
#  'accor',
#  'accord',
#  'accordance',
#  'accordeon',
#  'accordingly',
#  'accordion',
#  'accoridng',
#  'accost',
#  'accound',
#  'account',
#  'accountability',
#  'accountable',
#  'accountancy',
#  'accountant',
#  'accountbalance',
#  'accountdeficit',
#  'accountsm',
#  'accounttotal',
#  'accout',
#  'accouting',
#  'accpet',
#  'accra',
#  'accredit',
#  'accreditation',
#  'accrete',
#  'accretion',
#  'accroding',
#  'accross',
#  'accrual',
#  'accrue',
#  'accruedinterest',
#  'acct',
#  'accts',
#  'accumulate',
#  'accumulation',
#  'accumulative',
#  'accumulator',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accusation',
#  'accuse',
#  'accuser',
#  'accussed',
#  'accustaff',
#  'accustom',
#  'accute',
#  'ace',
#  'acea',
#  'acebes',
#  'acedera',
#  'aceh',
#  'acer',
#  'acerbic',
#  'acero',
#  'acertificate',
#  'acetate',
#  'acetylcholine',
#  'aceval',
#  'aceveda',
#  'acevedo',
#  'acf',
#  'acg',
#  'ach',
#  'achard',
#  'acharya',
#  'achats',
#  'ache',
#  'acheampong',
#  'acheive',
#  'acheived',
#  'acheivements',
#  'acher',
#  'acheson',
#  'achi',
#  'achiev',
#  'achieva',
#  'achievable',
#  'achieve',
#  'achieveable',
#  'achievement',
#  'achiever',
#  'achievment',
#  'achievments',
#  'achille',
#  'achillea',
#  'achilles',
#  'achim',
#  'achinsky',
#  'achirafi',
#  'achive',
#  'achna',
#  'achon',
#  'aci',
#  'acid',
#  'acimovic',
#  'acitibank',
#  'acitivity',
#  'ackerman',
#  'ackermann',
#  'acket',
#  'acklin',
#  'acknowleded',
#  'acknowledge',
#  'acknowledgement',
#  'acknowledgment',
#  'acknowleding',
#  'acknowlege',
#  'acknowleged',
#  'ackowledged',
#  'ackramdeputy',
#  'acl',
#  'aclothes',
#  'aclu',
#  'acm',
#  'acme',
#  'acoholic',
#  'acolonial',
#  'acolyte',
#  'acombined',
#  'acommonwealth',
#  'acompany',
#  'acompetitive',
#  'acompos',
#  'aconsolidated',
#  'aconstruction',
#  'acording',
#  'acores',
#  'acorn',
#  'acoss',
#  'acosta',
#  'acount',
#  'acounts',
#  'acoustic',
#  'acp',
#  'acpc',
#  'acpi',
#  'acq',
#  'acquaint',
#  'acquaintance',
#  'acquiesce',
#  'acquiescence',
#  'acquiescent',
#  'acquiesence',
#  'acquire',
#  'acquis',
#  'acquisition',
#  'acquisitionand',
#  'acquistion',
#  'acquit',
#  'acquital',
#  'acquittal',
#  'acr',
#  'acre',
#  'acreage',
#  'acree',
#  'acrid',
#  'acrimonious',
#  'acrimoniously',
#  'acrimony',
#  'acro',
#  'acrobat',
#  'acrobatic',
#  'acrobatically',
#  'acrobatics',
#  'acronym',
#  'acropolis',
#  'acrylic',
#  'acska',
#  'acsp',
#  'act',
#  'action',
#  'actionaid',
#  'actionnaires',
#  'actitivities',
#  'activate',
#  'activation',
#  'active',
#  'actively',
#  'activies',
#  'activism',
#  'activist',
#  'activites',
#  'activitists',
#  'activitiy',
#  'activity',
#  'activty',
#  'acton',
#  'actor',
#  'actress',
#  'actu',
#  'actual',
#  'actualexchange',
#  'actualisation',
#  'actualite',
#  'actually',
#  'actuals',
#  'actuarial',
#  'actuarially',
#  'actuary',
#  'actuator',
#  'actuel',
#  'actuelle',
#  'actuellement',
#  'actuelles',
#  'acu',
#  'acuff',
#  'acumen',
#  'acuna',
#  'acupuncture',
#  'acupuncturist',
#  'acura',
#  'acurrent',
#  'acushnet',
#  'acutally',
#  'acute',
#  'acutely',
#  'acuteness',
#  'acw',
#  'acy',
#  'ada',
#  'adachi',
#  'adage',
#  'adailton',
#  'adair',
#  'adak',
#  'adalbert',
#  'adalberto',
#  'adam',
#  'adama',
#  'adamafio',
#  'adamant',
#  'adamantly',
#  'adamas',
#  'adamczyk',
#  'adami',
#  'adamilabour',
#  'adamo',
#  'adamsbowling',
#  'adamson',
#  'adamtransport',
#  'adamu',
#  'adamy',
#  'adan',
#  'adana',
#  'adani',
#  'adapt',
#  'adaptability',
#  'adaptable',
#  'adaptation',
#  'adapter',
#  'adaption',
#  'adaptive',
#  'adaptment',
#  'adar',
#  'adare',
#  'adated',
#  'adb',
#  'adbul',
#  'adc',
#  'adcock',
#  'add',
#  'addded',
#  'addedthat',
#  'addedthe',
#  'addendum',
#  'addendummsrb',
#  'addicks',
#  'addict',
#  'addiction',
#  'addictive',
#  'addington',
#  'addis',
#  'addison',
#  'addition',
#  'additional',
#  'additionally',
#  'additionalofficial',
#  'additive',
#  'additonal',
#  'addo',
#  'addoum',
#  'address',
#  'addtional',
#  'addu',
#  'adduce',
#  'ade',
#  'adeba',
#  'adebanjo',
#  'adebayo',
#  'adeberg',
#  'adebiyi',
#  'adec',
#  'aded',
#  'adedavo',
#  'adedayo',
#  'adedy',
#  'adefa',
#  'adeficit',
#  'adeishvili',
#  'adel',
#  'adelaide',
#  'adelboden',
#  'adele',
#  'adelekan',
#  'adelie',
#  'adeline',
#  'adelino',
#  'adelivery',
#  'adelman',
#  'adelmann',
#  'adem',
#  'adema',
#  'ademola',
#  'aden',
#  'adenauer',
#  'adeng',
#  'adenovirus',
#  'adepojo',
#  'adepoju',
#  'adept',
#  'adequacy',
#  'adequate',
#  'adequately',
#  'ader',
#  'adere',
#  'adesanya',
#  'adesina',
#  'adeutsche',
#  'adevarul',
#  'adey',
#  'adf',
#  'adfl',
#  'adha',
#  'adherance',
#  'adhere',
#  'adherence',
#  'adherent',
#  'adhesion',
#  'adhesive',
#  'adhikary',
#  'adi',
#  'adib',
#  'adidas',
#  'adieu',
#  'adige',
#  'adil',
#  'adilson',
#  'adiministration',
#  'adineh',
#  'adios',
#  'adireksan',
#  'adireksarn',
#  'adirondack',
#  'adirondacks',
#  'adisa',
#  'aditya',
#  'adivser',
#  'adiyasuren',
#  'adj',
#  'adjacent',
#  'adjani',
#  'adjat',
#  'adjective',
#  'adjei',
#  'adji',
#  'adjoin',
#  'adjoudji',
#  'adjourn',
#  'adjournment',
#  'adjudge',
#  'adjudicate',
#  'adjudication',
#  'adjudicator',
#  'adjunct',
#  'adjuseted',
#  'adjust',
#  'adjustable',
#  'adjustedbalance',
#  'adjustedlatest',
#  'adjustement',
#  'adjustment',
#  'adkins',
#  'adkinson',
#  'adl',
#  'adlal',
#  'adlam',
#  'adler',
#  'adlon',
#  'adm',
#  'admg',
#  'admin',
#  'admininstration',
#  'adminisration',
#  'administation',
#  'administator',
#  'administer',
#  'administraiton',
#  'administrate',
#  'administration',
#  'administrationdepartment',
#  'administrationinfrastructure',
#  'administrationpercent',
#  'administrationre',
#  'administrative',
#  'administratively',
#  'administrativesupervision',
#  'administraton',
#  'administrator',
#  'adminsitration',
#  'adminstration',
#  'adminstrations',
#  'adminstrative',
#  'adminstrator',
#  'adminstrators',
#  'admira',
#  'admirable',
#  'admirably',
#  'admiral',
#  'admiralty',
#  'admiration',
#  'admire',
#  'admirer',
#  'admiringly',
#  'admissable',
#  'admissible',
#  'admission',
#  'admistration',
#  'admit',
#  'admittance',
#  'admittedly',
#  'adml',
#  'admninistration',
#  'admonish',
#  'admonishment',
#  'admonition',
#  'adn',
#  'adnan',
#  'adne',
#  'ado',
#  'adobe',
#  'adolescence',
#  'adolescent',
#  'adolf',
#  'adolfo',
#  'adolfson',
#  'adolph',
#  'adoped',
#  'adopt',
#  'adoption',
#  'adoptive',
#  'adoration',
#  'adore',
#  'adorn',
#  'adornment',
#  'adoum',
#  'adouyan',
#  'adp',
#  'adr',
#  'adran',
#  'adraw',
#  'adrenalin',
#  'adrenaline',
#  'adrenoleukodystrophy',
#  'adresdner',
#  'adress',
#  'adressed',
#  'adressing',
#  'adri',
#  'adria',
#  'adriaan',
#  ...]

# %%
from sklearn.externals import joblib

# %%
joblib.dump(count_vectorizer_with_stem, 'count_vectorizer_with_stem.pkl')
# Out:
# ['count_vectorizer_with_stem.pkl']
